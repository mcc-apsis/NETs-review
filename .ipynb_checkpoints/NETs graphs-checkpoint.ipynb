# %%
import django, os, sys, time, resource, re, gc, shutil
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from django.db.models import Count, Avg, F

sys.path.append('/home/galm/software/django/tmv/BasicBrowser/')

os.environ.setdefault("DJANGO_SETTINGS_MODULE", "BasicBrowser.settings")
django.setup()

from scoping.models import *

# %%
p = Project.objects.get(title="NETs")
pdocs = Doc.objects.filter(query__project=p) | Doc.objects.filter(technology__project=p)

trdocs = set(list(pdocs.filter(docownership__relevant=1).values_list('UT',flat=True)))

irdocs = set(list(pdocs.filter(docownership__relevant=5).values_list('UT',flat=True)))

inrateddocs = set(list(pdocs.filter(docownership__relevant__in=[5,6,7,8]).values_list('UT',flat=True)))

# %%
print(len(trdocs))
print(len(irdocs))
print(len(inrateddocs))

print(len(trdocs.intersection(inrateddocs)))

allreldocs = pdocs.distinct().filter(
    UT__in=trdocs.intersection(irdocs)
)

print(allreldocs.count())
# Out:
# 1777
# 1792
# 2399
# 891
# 675

# %%
weird = irdocs.difference(trdocs)
weird
# Out:
# {'WOS:000376711000007',
#  'WOS:000316606100008',
#  'WOS:000258823800004',
#  'WOS:000330814100055',
#  'WOS:000375125200011',
#  'WOS:000365070700050',
#  'WOS:000279258000030',
#  'WOS:000374592800007',
#  'WOS:000392677200006',
#  'WOS:000275841100015',
#  'WOS:000244055300007',
#  'WOS:000366402900019',
#  'WOS:000388944200005',
#  'WOS:000365026600030',
#  'WOS:000286905300053',
#  'WOS:000389088400005',
#  'WOS:000356936200054',
#  'WOS:000316002800013',
#  'WOS:000337017700006',
#  'WOS:000316032300046',
#  'WOS:000245987300005',
#  'WOS:000243803300003',
#  'WOS:000379208400032',
#  'WOS:000323253500039',
#  'WOS:000380033400033',
#  'WOS:000363531900012',
#  'WOS:000273754800022',
#  'WOS:000330965400010',
#  'WOS:000170758900011',
#  'WOS:000325665400010',
#  'WOS:000339216600004',
#  'WOS:000263358500008',
#  'WOS:000251685100001',
#  'WOS:000364247100083',
#  'WOS:000227183600005',
#  'WOS:000243609800002',
#  'WOS:000370096200009',
#  'WOS:000345075400007',
#  'WOS:000376806900010',
#  'WOS:000332815300064',
#  'WOS:000351849700025',
#  'WOS:000179964100006',
#  'WOS:000376839400004',
#  'WOS:000343679800053',
#  'WOS:000351975000003',
#  'WOS:000349562000026',
#  'WOS:000325717200002',
#  'WOS:000327090000008',
#  'WOS:000243284900003',
#  'WOS:000378852000006',
#  'WOS:000364087900012',
#  'WOS:000315238600012',
#  'WOS:000323221500133',
#  'WOS:000175749000001',
#  'WOS:000282273700004',
#  'WOS:000277002900013',
#  'WOS:000257286800007',
#  'WOS:000291735500008',
#  'WOS:000384782800044',
#  'WOS:000377602000006',
#  'WOS:000382136500014',
#  'WOS:000303220900001',
#  'WOS:000272383900017',
#  'WOS:000319289700008',
#  'WOS:000363255100011',
#  'WOS:000267478000010',
#  'WOS:000333781800017',
#  'WOS:000357225500019',
#  'WOS:000300743400010',
#  'WOS:000270122100018',
#  'WOS:000384913000019',
#  'WOS:000378434700007',
#  'WOS:000292041500007',
#  'WOS:000287336000003',
#  'WOS:000373541400005',
#  'WOS:000263768200002',
#  'WOS:000329144400011',
#  'WOS:000359278400023',
#  'WOS:000252018600011',
#  'WOS:000303392200007',
#  'WOS:000380803600042',
#  'WOS:000366769300012',
#  'WOS:000285903400018',
#  'WOS:000364166700010',
#  'WOS:000349726300019',
#  'WOS:000349895300017',
#  'WOS:000301327300023',
#  'WOS:000341099200009',
#  'WOS:000361255400025',
#  'WOS:000228955400006',
#  'WOS:000330036700020',
#  'WOS:000311932200022',
#  'WOS:000371948400113',
#  'WOS:000367757200008',
#  'WOS:000331017100004',
#  'WOS:000248897000001',
#  'WOS:000173065800014',
#  'WOS:000389089800032',
#  'WOS:000286088700004',
#  'WOS:000310053000007',
#  'WOS:000358443300001',
#  'WOS:000282218400015',
#  'WOS:000350549000002',
#  'WOS:000271279100026',
#  'WOS:000253750100004',
#  'WOS:A1996UH13900002',
#  'WOS:A1995RG56600008',
#  'WOS:000390503400008',
#  'WOS:000285574100008',
#  'WOS:000370371900007',
#  'WOS:000318261000055',
#  'WOS:000319155200002',
#  'WOS:000072198600011',
#  'WOS:000371082800001',
#  'WOS:000292859600003',
#  'WOS:000329429800011',
#  'WOS:000289003600009',
#  'WOS:000346398600018',
#  'WOS:000288474300009',
#  'WOS:000322056600007',
#  'WOS:000240990800001',
#  'WOS:000284159900001',
#  'WOS:000332133100013',
#  'WOS:000370086200039',
#  'WOS:000293048700008',
#  'WOS:000335892400003',
#  'WOS:000379366500002',
#  'WOS:000319162300007',
#  'WOS:000327814700031',
#  'WOS:000272656700001',
#  'WOS:000384432600009',
#  'WOS:000258211600033',
#  'WOS:000305966900025',
#  'WOS:000377738500017',
#  'WOS:000251917000026',
#  'WOS:000294702500020',
#  'WOS:000261964100001',
#  'WOS:000321123800056',
#  'WOS:000294373200067',
#  'WOS:000359384500012',
#  'WOS:000379507100001',
#  'WOS:000345915300018',
#  'WOS:000300661800017',
#  'WOS:000345229700008',
#  'WOS:000290924400001',
#  'WOS:000343845400002',
#  'WOS:000254694200001',
#  'WOS:000377372400005',
#  'WOS:000240997100002',
#  'WOS:000367460000009',
#  'WOS:000360586100003',
#  'WOS:000390466900008',
#  'WOS:000364328300019',
#  'WOS:000245377700015',
#  'WOS:000388580200064',
#  'WOS:000381828300014',
#  'WOS:000381834100006',
#  'WOS:000367156000003',
#  'WOS:000292675300009',
#  'WOS:000336700100010',
#  'WOS:000305931200012',
#  'WOS:000305966900024',
#  'WOS:A1993LF20700002',
#  'WOS:000295658700007',
#  'WOS:000244396800005',
#  'WOS:000318684200005',
#  'WOS:000325591700011',
#  'WOS:000345979700066',
#  'WOS:000237257600002',
#  'WOS:000384724700015',
#  'WOS:000347545800027',
#  'WOS:000282014300004',
#  'WOS:000083008000012',
#  'WOS:000261925200020',
#  'WOS:000309376200004',
#  'WOS:000370816300016',
#  'WOS:000303956900028',
#  'WOS:000339633200004',
#  'WOS:000349504300027',
#  'WOS:000340701800022',
#  'WOS:000347498100001',
#  'WOS:000368638700008',
#  'WOS:000274813800017',
#  'WOS:000368200200091',
#  'WOS:000367982900006',
#  'WOS:000368569500002',
#  'WOS:000260970900026',
#  'WOS:000302580600036',
#  'WOS:000357275200005',
#  'WOS:000322426400023',
#  'WOS:000350202300004',
#  'WOS:000317328200008',
#  'WOS:000339048900023',
#  'WOS:000234974900015',
#  'WOS:000359880600042',
#  'WOS:000334588300007',
#  'WOS:000340652100051',
#  'WOS:000338612500029',
#  'WOS:000307222700023',
#  'WOS:000339332100004',
#  'WOS:000209196200002',
#  'WOS:000260230000003',
#  'WOS:000377934400011',
#  'WOS:000247977700016',
#  'WOS:000237516200003',
#  'WOS:000282613300001',
#  'WOS:000390216800016',
#  'WOS:000283092300004',
#  'WOS:000346648400010',
#  'WOS:000301881700010',
#  'WOS:000267152500003',
#  'WOS:000340099400016',
#  'WOS:000383466800036',
#  'WOS:000347510800005',
#  'WOS:000276440000007',
#  'WOS:000348667900018',
#  'WOS:000321309600006',
#  'WOS:000339700200002',
#  'WOS:000259503200008',
#  'WOS:000234504000004',
#  'WOS:000389316400008',
#  'WOS:000375120600005',
#  'WOS:000285070700007',
#  'WOS:000362134400023',
#  'WOS:000184311800026',
#  'WOS:000178081800005',
#  'WOS:000375517900003',
#  'WOS:000320423300020',
#  'WOS:000370909500020',
#  'WOS:000289605900021',
#  'WOS:000387581400003',
#  'WOS:000294645500002',
#  'WOS:000362985200004',
#  'WOS:000233365300017',
#  'WOS:000184694100006',
#  'WOS:000299610900012',
#  'WOS:000313154900021',
#  'WOS:000258201000008',
#  'WOS:000387596900014',
#  'WOS:000242050600022',
#  'WOS:000317952200008',
#  'WOS:000301617000005',
#  'WOS:000245795900005',
#  'WOS:000392425800007',
#  'WOS:000232893000009',
#  'WOS:000257286800006',
#  'WOS:000184414400004',
#  'WOS:000381833200013',
#  'WOS:000251149800005',
#  'WOS:000269435400005',
#  'WOS:000376579000004',
#  'WOS:000347128400007',
#  'WOS:000382826400010',
#  'WOS:000284672800042',
#  'WOS:000276226100001',
#  'WOS:000328716600005',
#  'WOS:000371896900012',
#  'WOS:000325116700016',
#  'WOS:000352719600013',
#  'WOS:000326767100020',
#  'WOS:000309670200004',
#  'WOS:000287853500001',
#  'WOS:000250702100001',
#  'WOS:000357344300003',
#  'WOS:000289102400001',
#  'WOS:000208863600287',
#  'WOS:000391090800025',
#  'WOS:000072916200006',
#  'WOS:000360705300003',
#  'WOS:000235666300002',
#  'WOS:000290587100012',
#  'WOS:000273185900002',
#  'WOS:000387157900001',
#  'WOS:000376825300017',
#  'WOS:000224648200004',
#  'WOS:000348399300033',
#  'WOS:000252663200009',
#  'WOS:000327934600001',
#  'WOS:000365362700080',
#  'WOS:000329871700012',
#  'WOS:000356936200059',
#  'WOS:000306952400012',
#  'WOS:000313390200002',
#  'WOS:000281922800015',
#  'WOS:A1993KM79000021',
#  'WOS:000297028000020',
#  'WOS:000378113200001',
#  'WOS:000370964000022',
#  'WOS:000257847500001',
#  'WOS:000297824500018',
#  'WOS:000282218400002',
#  'WOS:000222309300003',
#  'WOS:A1992HE56700005',
#  'WOS:000393000500004',
#  'WOS:000325739100012',
#  'WOS:000295297300028',
#  'WOS:A1975AD98400004',
#  'WOS:000392789000073',
#  'WOS:000261766900005',
#  'WOS:000361782800001',
#  'WOS:000346664200001',
#  'WOS:A1997XF04800007',
#  'WOS:000256143900032',
#  'WOS:000328179400050',
#  'WOS:000354342500050',
#  'WOS:000310945600024',
#  'WOS:000335096900012',
#  'WOS:000339332100009',
#  'WOS:000285985800009',
#  'WOS:000290016000012',
#  'WOS:000351898400004',
#  'WOS:000307418600007',
#  'WOS:000387298100013',
#  'WOS:000342581400021',
#  'WOS:000286999200006',
#  'WOS:000288306700023',
#  'WOS:000166441700002',
#  'WOS:000342552800034',
#  'WOS:000298227400005',
#  'WOS:000368745000026',
#  'WOS:000178558900005',
#  'WOS:000264923600001',
#  'WOS:000286343000012',
#  'WOS:000335113200004',
#  'WOS:000297735100005',
#  'WOS:000086975800005',
#  'WOS:000274945200002',
#  'WOS:000182549500004',
#  'WOS:000286527400006',
#  'WOS:000333259100006',
#  'WOS:000292483400013',
#  'WOS:000315388200009',
#  'WOS:000322562000003',
#  'WOS:000313417400012',
#  'WOS:000178964000026',
#  'WOS:000295153300015',
#  'WOS:000329550700007',
#  'WOS:000375605400003',
#  'WOS:000254072700037',
#  'WOS:000296671300008',
#  'WOS:000165610900008',
#  'WOS:000344168400012',
#  'WOS:000234750100009',
#  'WOS:000325894100073',
#  'WOS:000303088200019',
#  'WOS:000290661300029',
#  'WOS:000297366900001',
#  'WOS:000381172000035',
#  'WOS:000269335400009',
#  'WOS:000363247700010',
#  'WOS:000083804900003',
#  'WOS:000366873500006',
#  'WOS:000317709100029',
#  'WOS:000338109700020',
#  'WOS:000365816000063',
#  'WOS:000380418900003',
#  'WOS:000365450800050',
#  'WOS:000360852600007',
#  'WOS:000236424800003',
#  'WOS:000309790500016',
#  'WOS:000387351200002',
#  'WOS:000386107200014',
#  'WOS:000281110200010',
#  'WOS:000386418200022',
#  'WOS:000082148200004',
#  'WOS:000330463600038',
#  'WOS:000228184500026',
#  'WOS:000367407200021',
#  'WOS:000329843100001',
#  'WOS:000372680900025',
#  'WOS:000223795000002',
#  'WOS:000282218400012',
#  'WOS:000375337400007',
#  'WOS:000381639700014',
#  'WOS:000341135700006',
#  'WOS:000276734300021',
#  'WOS:000330617100015',
#  'WOS:000370870500001',
#  'WOS:000231721000028',
#  'WOS:000287974900013',
#  'WOS:000184929200020',
#  'WOS:000234504000002',
#  'WOS:000384851000030',
#  'WOS:000323642700014',
#  'WOS:000173065800002',
#  'WOS:000230170600002',
#  'WOS:000315388200006',
#  'WOS:000325101500014',
#  'WOS:000319891900020',
#  'WOS:000348459400018',
#  'WOS:000316307200021',
#  'WOS:000300051500003',
#  'WOS:000305093500003',
#  'WOS:000209183900002',
#  'WOS:000369859900003',
#  'WOS:000389912200017',
#  'WOS:000299166300030',
#  'WOS:000388775400019',
#  'WOS:000248469700008',
#  'WOS:000344920200001',
#  'WOS:000366074400035',
#  'WOS:000339129500005',
#  'WOS:000364024300027',
#  'WOS:000351963400029',
#  'WOS:000244706300001',
#  'WOS:000350751000007',
#  'WOS:000349853500003',
#  'WOS:000276705300007',
#  'WOS:000333720300012',
#  'WOS:000290011800016',
#  'WOS:000295515200005',
#  'WOS:000373376700015',
#  'WOS:000326905400055',
#  'WOS:000389288900020',
#  'WOS:000376705400001',
#  'WOS:000305966900006',
#  'WOS:000316272400007',
#  'WOS:000274285300003',
#  'WOS:000374592800010',
#  'WOS:000316946500015',
#  'WOS:000369556700005',
#  'WOS:000167612600002',
#  'WOS:000336890200010',
#  'WOS:000228604000007',
#  'WOS:000356642300002',
#  'WOS:000381544000002',
#  'WOS:000282621500005',
#  'WOS:000270210200011',
#  'WOS:000262730100001',
#  'WOS:000306318300002',
#  'WOS:000359747200007',
#  'WOS:000369200100010',
#  'WOS:000264653600022',
#  'WOS:000249915500017',
#  'WOS:000272135600005',
#  'WOS:000314675500007',
#  'WOS:000319708600024',
#  'WOS:000317145800019',
#  'WOS:000075594000004',
#  'WOS:000367757200015',
#  'WOS:000388472800002',
#  'WOS:000284294600038',
#  'WOS:000207892100002',
#  'WOS:000279224000003',
#  'WOS:000321894400001',
#  'WOS:000335434400025',
#  'WOS:000295125700003',
#  'WOS:000259136700006',
#  'WOS:000305966900026',
#  'WOS:000292853100004',
#  'WOS:000359384500009',
#  'WOS:000253340700004',
#  'WOS:000317093200034',
#  'WOS:000364611300003',
#  'WOS:000315079300010',
#  'WOS:000079238600002',
#  'WOS:000270278000001',
#  'WOS:000368199300047',
#  'WOS:000207892400001',
#  'WOS:000286450700015',
#  'WOS:000250582500002',
#  'WOS:000286431900016',
#  'WOS:000277869800010',
#  'WOS:000376282600007',
#  'WOS:000370170100002',
#  'WOS:000330150300005',
#  'WOS:000273301100003',
#  'WOS:000266942900034',
#  'WOS:000299147500007',
#  'WOS:000393577900001',
#  'WOS:000288313100011',
#  'WOS:000292859300003',
#  'WOS:000183102900006',
#  'WOS:000305664700006',
#  'WOS:000337946400003',
#  'WOS:000275009400014',
#  'WOS:000349723500066',
#  'WOS:000345474800003',
#  'WOS:000325671900006',
#  'WOS:000333138100004',
#  'WOS:000277692300007',
#  'WOS:000341349300008',
#  'WOS:000341230500001',
#  'WOS:000290698100008',
#  'WOS:000359384500020',
#  'WOS:000355715600031',
#  'WOS:000334002700016',
#  'WOS:000358150400126',
#  'WOS:000316013500002',
#  'WOS:000372319700015',
#  'WOS:000388735900010',
#  'WOS:000385901200022',
#  'WOS:000350524700029',
#  'WOS:000306199400003',
#  'WOS:000363331900025',
#  'WOS:000327911000030',
#  'WOS:000389302100019',
#  'WOS:000343164600016',
#  'WOS:000284669300010',
#  'WOS:000295183600002',
#  'WOS:000392271400004',
#  'WOS:000388477100002',
#  'WOS:000253779900006',
#  'WOS:000316740800008',
#  'WOS:000334354400002',
#  'WOS:000369537000009',
#  'WOS:000377372400038',
#  'WOS:000251302500013',
#  'WOS:000220551500040',
#  'WOS:000371797900038',
#  'WOS:000380295700049',
#  'WOS:000222206300007',
#  'WOS:000306228300021',
#  'WOS:000223361500007',
#  'WOS:000380149200001',
#  'WOS:000271980800132',
#  'WOS:000373138000006',
#  'WOS:000343614400033',
#  'WOS:000296568500017',
#  'WOS:000267404000007',
#  'WOS:000316707800008',
#  'WOS:000265279500004',
#  'WOS:000343761600001',
#  'WOS:000350520000007',
#  'WOS:000337514900015',
#  'WOS:000330740600006',
#  'WOS:000284762400035',
#  'WOS:000394395800012',
#  'WOS:000349618700001',
#  'WOS:000312454900002',
#  'WOS:000298227400003',
#  'WOS:000352205900011',
#  'WOS:000340698600005',
#  'WOS:000367880700031',
#  'WOS:A1974V019100010',
#  'WOS:000316998300074',
#  'WOS:000379568400001',
#  'WOS:000184605700001',
#  'WOS:000176208200001',
#  'WOS:000220102700016',
#  'WOS:000362897400005',
#  'WOS:000351646800010',
#  'WOS:000326767100031',
#  'WOS:000257713300004',
#  'WOS:000253180800009',
#  'WOS:000378781700010',
#  'WOS:000333979300022',
#  'WOS:000255251800007',
#  'WOS:000375167100009',
#  'WOS:000353149900015',
#  'WOS:000347582800019',
#  'WOS:000361782800006',
#  'WOS:000371918800011',
#  'WOS:000246168000002',
#  'WOS:000374329900008',
#  'WOS:000310396100062',
#  'WOS:000326944000003',
#  'WOS:000347018400023',
#  'WOS:000333615800007',
#  'WOS:000288571700012',
#  'WOS:000348927000003',
#  'WOS:000379014900012',
#  'WOS:000358805000022',
#  'WOS:000222173600040',
#  'WOS:000327027200007',
#  'WOS:000232902200014',
#  'WOS:000334978000023',
#  'WOS:000326158600005',
#  'WOS:000368686500013',
#  'WOS:000209832600004',
#  'WOS:000228053700001',
#  'WOS:000395001800005',
#  'WOS:000239864300018',
#  'WOS:000349504300004',
#  'WOS:000237052200011',
#  'WOS:000167669600011',
#  'WOS:000185817300010',
#  'WOS:000372680100001',
#  'WOS:000231598900002',
#  'WOS:000263018400005',
#  'WOS:000329429800021',
#  'WOS:000285108700001',
#  'WOS:000299983700014',
#  'WOS:000361782800004',
#  'WOS:000258017600003',
#  'WOS:000332591700012',
#  'WOS:000257619400011',
#  'WOS:000242670300009',
#  'WOS:000167899400005',
#  'WOS:000319961900052',
#  'WOS:000270321900018',
#  'WOS:000236254700001',
#  'WOS:000243200100005',
#  'WOS:000321122700019',
#  'WOS:000253913400015',
#  'WOS:000352112900001',
#  'WOS:000238637900025',
#  'WOS:000332439800028',
#  'WOS:000288738900013',
#  'WOS:000342443000001',
#  'WOS:000381060900073',
#  'WOS:000238258700008',
#  'WOS:000259390300003',
#  'WOS:000251948500009',
#  'WOS:000327998600015',
#  'WOS:000357123100001',
#  'WOS:000317548000006',
#  'WOS:000343569800001',
#  'WOS:000313318000051',
#  'WOS:000276479700007',
#  'WOS:000350011700005',
#  'WOS:000269246200001',
#  'WOS:000282978100003',
#  'WOS:000384776800029',
#  'WOS:000231877900004',
#  'WOS:000327400400004',
#  'WOS:000249151000008',
#  'WOS:000181863700014',
#  'WOS:000330322200002',
#  'WOS:000208847300023',
#  'WOS:000389555900001',
#  'WOS:000318582500009',
#  'WOS:000335369100018',
#  'WOS:000366965200100',
#  'WOS:000371515300005',
#  'WOS:000298059900008',
#  'WOS:000291739700007',
#  'WOS:A1995TC11000011',
#  'WOS:000390727600030',
#  'WOS:000262849800008',
#  'WOS:000365931600024',
#  'WOS:000299864400019',
#  'WOS:000385154400003',
#  'WOS:000330202600016',
#  'WOS:000305966900007',
#  'WOS:000332060400001',
#  'WOS:000392105700095',
#  'WOS:000295523500001',
#  'WOS:000257757700024',
#  'WOS:000284631400004',
#  'WOS:000355841500008',
#  'WOS:000389785200081',
#  'WOS:000260149300009',
#  'WOS:000367635800031',
#  'WOS:000359371800020',
#  'WOS:000314270400018',
#  'WOS:000316909400009',
#  'WOS:000243555300008',
#  'WOS:000086715100018',
#  'WOS:000378183900059',
#  'WOS:000387790100003',
#  'WOS:000372238400005',
#  'WOS:000310069200011',
#  'WOS:000375365300020',
#  'WOS:000346611400014',
#  'WOS:000282218400003',
#  'WOS:000321063800015',
#  'WOS:000291253300020',
#  'WOS:000353905900001',
#  'WOS:000341230200024',
#  'WOS:000307620800005',
#  'WOS:000369315000005',
#  'WOS:000286675500003',
#  'WOS:000286672600002',
#  'WOS:000302188300006',
#  'WOS:000334514000020',
#  'WOS:000270152300049',
#  'WOS:A1992JA73600059',
#  'WOS:000387300300001',
#  'WOS:000331674600002',
#  'WOS:000294700900001',
#  'WOS:000074431800003',
#  'WOS:000326396600029',
#  'WOS:000274347800023',
#  'WOS:000287830400006',
#  'WOS:000267897500002',
#  'WOS:000176265200022',
#  'WOS:000358809400018',
#  'WOS:000385598800040',
#  'WOS:000307201200002',
#  'WOS:000304897500011',
#  'WOS:000353097200003',
#  'WOS:000313390200004',
#  'WOS:000278038000004',
#  'WOS:000270226200009',
#  'WOS:000370909500027',
#  'WOS:000384857100004',
#  'WOS:000356119000016',
#  'WOS:A1997XR58700006',
#  'WOS:000348087800005',
#  'WOS:000361824300033',
#  'WOS:000372701200084',
#  'WOS:000337146500016',
#  'WOS:000274350400015',
#  'WOS:A1996VV19900008',
#  'WOS:000386310900012',
#  'WOS:000387616700006',
#  'WOS:000353428600002',
#  'WOS:000365433300024',
#  'WOS:000324152800001',
#  'WOS:000315383200014',
#  'WOS:000250260100002',
#  'WOS:000388553800004',
#  'WOS:000321871000010',
#  'WOS:000329094600017',
#  'WOS:000226285000015',
#  'WOS:000342226600008',
#  'WOS:000177340500021',
#  'WOS:000328179400011',
#  'WOS:000262053400010',
#  'WOS:000338430700048',
#  'WOS:000278889600004',
#  'WOS:000082049300001',
#  'WOS:000082940100001',
#  'WOS:000311982600009',
#  'WOS:000331224000002',
#  'WOS:000381534200004',
#  'WOS:000282071800012',
#  'WOS:A1993NK62900009',
#  'WOS:000362227500016',
#  'WOS:000254798800001',
#  'WOS:000377633900001',
#  'WOS:000293591800001',
#  'WOS:000365289300027',
#  'WOS:000271708300020',
#  'WOS:000175709800001',
#  'WOS:000291577300011',
#  'WOS:000372680100005',
#  'WOS:000368733800001',
#  'WOS:000173848000012',
#  'WOS:000361772800009',
#  'WOS:000356119000003',
#  'WOS:000374060500008',
#  'WOS:A1992JW94500060',
#  'WOS:000241222800001',
#  'WOS:000326767100022',
#  'WOS:000320144700001',
#  'WOS:000304507400011',
#  'WOS:000255627200008',
#  'WOS:000252763100010',
#  'WOS:000308400100006',
#  'WOS:A1994PK57500003',
#  'WOS:000365644600007',
#  'WOS:000365368400016',
#  'WOS:000250802500010',
#  'WOS:A1994NM25200002',
#  'WOS:000257286800011',
#  'WOS:000358807000010',
#  'WOS:000231881600005',
#  'WOS:000290924400008',
#  'WOS:000365032100011',
#  'WOS:000287903300006',
#  'WOS:000221660300007',
#  'WOS:000250260100023',
#  'WOS:000378212400010',
#  'WOS:000308577600013',
#  'WOS:000362210800004',
#  'WOS:000188422300003',
#  'WOS:000295815400043',
#  'WOS:000290277200005',
#  'WOS:000370885800007',
#  'WOS:000323471700050',
#  'WOS:000249064000003',
#  'WOS:000385529400013',
#  'WOS:A1997XK65100004',
#  'WOS:000325465300021',
#  'WOS:000316827500002',
#  'WOS:000263981700001',
#  'WOS:000265168800024',
#  'WOS:000377792800026',
#  'WOS:000321067600008',
#  'WOS:000384057800002',
#  'WOS:000347266700002',
#  'WOS:000373700800009',
#  'WOS:000207663000003',
#  'WOS:000187290000001',
#  'WOS:000317702600025',
#  'WOS:000315414900016',
#  'WOS:000378188600023',
#  'WOS:000235980500011',
#  'WOS:000390021800003',
#  'WOS:000275356800003',
#  'WOS:000372963900015',
#  'WOS:000277732800009',
#  'WOS:000349590100012',
#  'WOS:000364195700006',
#  'WOS:000320425800019',
#  'WOS:000266358900008',
#  'WOS:000393108900003',
#  'WOS:000183554600003',
#  'WOS:000180656700007',
#  'WOS:000371523800002',
#  'WOS:000166357000003',
#  'WOS:000340947700092',
#  'WOS:000175872600006',
#  'WOS:000351871500017',
#  'WOS:000348520600005',
#  'WOS:000389634800012',
#  'WOS:000305966900014',
#  'WOS:000260242600002',
#  'WOS:000309312600005',
#  'WOS:000362359900001',
#  'WOS:000308970500012',
#  'WOS:000303355500006',
#  'WOS:000286957100002',
#  'WOS:000361189800049',
#  'WOS:000390727600041',
#  'WOS:000356491400006',
#  'WOS:000184338200001',
#  'WOS:000365335000024',
#  'WOS:000295124900003',
#  'WOS:000336778400017',
#  'WOS:000292427800064',
#  'WOS:000292533700001',
#  'WOS:000361159800021',
#  'WOS:000376802600017',
#  'WOS:000347019700005',
#  'WOS:000285096700011',
#  'WOS:000368342900047',
#  'WOS:000312617400007',
#  'WOS:000329871700007',
#  'WOS:000086553300007',
#  'WOS:000382138400020',
#  'WOS:000298452200013',
#  'WOS:000347263300014',
#  'WOS:000323479900021',
#  'WOS:000249183200003',
#  'WOS:000334446000010',
#  'WOS:000297812200009',
#  'WOS:000358782700008',
#  'WOS:000337994300010',
#  'WOS:000347148900012',
#  'WOS:000316190200054',
#  'WOS:000363691600008',
#  'WOS:000173973400001',
#  'WOS:000264950700015',
#  'WOS:000343762800021',
#  'WOS:000173501400001',
#  'WOS:000313667400021',
#  'WOS:000348526000007',
#  'WOS:000316391400023',
#  'WOS:000361378200009',
#  'WOS:000342530000032',
#  'WOS:000347739600022',
#  'WOS:000383358000004',
#  'WOS:000342530000052',
#  'WOS:000336188900008',
#  'WOS:000382397900005',
#  'WOS:000338693500025',
#  'WOS:000372943900005',
#  'WOS:000333782500013',
#  'WOS:000376282600009',
#  'WOS:000275536700009',
#  'WOS:000385605500004',
#  'WOS:000324152800002',
#  'WOS:000261843700010',
#  'WOS:000347907900012',
#  'WOS:000265342200017',
#  'WOS:000326905400027',
#  'WOS:000301190000025',
#  'WOS:000284745900005',
#  'WOS:000358968000066',
#  'WOS:000300070300002',
#  'WOS:000208650000020',
#  'WOS:A1994NZ28700002',
#  'WOS:000350534200016',
#  'WOS:000372171700014',
#  'WOS:000169102600004',
#  'WOS:000304290100003',
#  'WOS:000276175700029',
#  'WOS:000365056700029',
#  'WOS:000270197600002',
#  'WOS:000384745900006',
#  'WOS:000346357100007',
#  'WOS:000301900200011',
#  'WOS:000357157300002',
#  'WOS:000074762000010',
#  'WOS:000361470100007',
#  'WOS:000348880600017',
#  'WOS:000335720100004',
#  'WOS:000352253900006',
#  'WOS:000234781600007',
#  'WOS:000344423500023',
#  'WOS:000311271200011',
#  'WOS:000223361500002',
#  'WOS:000299109100009',
#  'WOS:000251050100012',
#  'WOS:000339554500061',
#  'WOS:000377296200008',
#  'WOS:000392886700009',
#  'WOS:000348899600007',
#  'WOS:000330819400012',
#  'WOS:000286677600005',
#  'WOS:000275223500030',
#  'WOS:000246854300017',
#  'WOS:000224095900004',
#  'WOS:000335567000002',
#  'WOS:000374994600006',
#  'WOS:000088713100004',
#  'WOS:000356119000007',
#  'WOS:000289054600043',
#  'WOS:000232893300005',
#  'WOS:000273917900006',
#  'WOS:000325076100003',
#  'WOS:000389292800009',
#  'WOS:000248421100001',
#  'WOS:000366776100008',
#  'WOS:000375136600003',
#  'WOS:000166089700004',
#  'WOS:000081781000009',
#  'WOS:000220224900001',
#  'WOS:000378764200044',
#  'WOS:000334298800020',
#  'WOS:000307199800007',
#  'WOS:000366793000011',
#  'WOS:000379038400009',
#  'WOS:000387570500015',
#  'WOS:000239189900059',
#  'WOS:000341468300021',
#  'WOS:000304810100005',
#  'WOS:000373085100001',
#  'WOS:000245795900004',
#  'WOS:000177611100007',
#  'WOS:000313600200017',
#  'WOS:000319838200003',
#  'WOS:000231532400010',
#  'WOS:000306062100002',
#  'WOS:000358004300024',
#  'WOS:000364257100027',
#  'WOS:000335912700010',
#  'WOS:000380907100020',
#  'WOS:000334005600003',
#  'WOS:000203094700012',
#  'WOS:000327923700012',
#  'WOS:000310952000015',
#  'WOS:000305966900004',
#  'WOS:000371515300003',
#  'WOS:000381577000073',
#  'WOS:000320425100004',
#  'WOS:000378788100029',
#  'WOS:000276497400001',
#  'WOS:000313871400034',
#  'WOS:000181195400002',
#  'WOS:000346545800012',
#  'WOS:000366775200003',
#  'WOS:000282727500040',
#  'WOS:000278742100022',
#  'WOS:000321150000043',
#  'WOS:000385738200009',
#  'WOS:000324695900100',
#  'WOS:000328801100005',
#  'WOS:000395001800011',
#  'WOS:000273756800009',
#  'WOS:000361536000023',
#  'WOS:000314193400014',
#  'WOS:000357147600023',
#  'WOS:000368958200011',
#  'WOS:000166235000016',
#  'WOS:000265969100005',
#  'WOS:000330096000077',
#  'WOS:000305281200006',
#  'WOS:000249776700002',
#  'WOS:000337651300013',
#  'WOS:000369630600004',
#  'WOS:000343839100011',
#  'WOS:000310741600018',
#  'WOS:000317537100058',
#  'WOS:000325671900002',
#  'WOS:000342492700112',
#  'WOS:000284261800015',
#  'WOS:000302294600011',
#  'WOS:000270475200002',
#  'WOS:000329429800008',
#  'WOS:000333780300009',
#  'WOS:000325600600027',
#  'WOS:000290192700007',
#  'WOS:000364605400012',
#  'WOS:000271370900018',
#  'WOS:A1996WG46800001',
#  'WOS:000319311400002',
#  'WOS:000366947400042',
#  'WOS:000188248100003',
#  'WOS:000176781800007',
#  'WOS:000292510400025',
#  'WOS:000270169300009',
#  'WOS:000247017500003',
#  'WOS:000358468900003',
#  'WOS:000294571700007',
#  'WOS:000376839400007',
#  'WOS:000282400200007',
#  'WOS:000380913500004',
#  'WOS:000353601500005',
#  'WOS:000273798900001',
#  'WOS:000375508800007',
#  'WOS:000315238500016',
#  'WOS:000300528800003',
#  'WOS:000185921100011',
#  'WOS:000291551500009',
#  'WOS:000311619500012',
#  'WOS:000359384500019',
#  ...}

# %%
for did in list(weird)[0:5]:
    d = Doc.objects.get(pk=did)
    print('\n############')
    print(d.UT)
    print(d.title)
    for x in d.query.all():
        print("id:{} u:{} t:{} i:{}".format(
            x.pk,
            x.creator,
            x.technology,
            x.innovation
        ))
# Out:
# ############
# WOS:000376711000007
# Pyrolysis of crop residues in a mobile bench-scale pyrolyser: Product characterization and environmental performance
# id:36 u:galm t:None i:None
# id:37 u:galm t:None i:None
# id:38 u:galm t:None i:None
# id:335 u:galm t:Biochar i:None
# id:336 u:galm t:Biochar i:None
# id:354 u:galm t:None i:None
# id:365 u:galm t:None i:None
# id:568 u:galm t:Biochar i:None
# id:894 u:galm t:None i:None
# id:1086 u:rogers t:None i:None
# id:1098 u:rogers t:None i:None
# id:1102 u:rogers t:None i:None
# id:1106 u:rogers t:None i:None
# id:1107 u:rogers t:None i:None
# id:1113 u:rogers t:None i:None
# id:1117 u:rogers t:None i:None
# id:1174 u:rogers t:None i:None
# id:1183 u:rogers t:None i:None
# id:1188 u:rogers t:Soil Carbon Sequestration i:Scaleup
# id:1192 u:rogers t:Soil Carbon Sequestration i:Innovationgeneral
# id:1284 u:rogers t:None i:None
# id:1285 u:rogers t:None i:None
# id:1304 u:rogers t:None i:None
# id:1497 u:lamw t:None i:None
#
# ############
# WOS:000316606100008
# Early Effects of Afforestation with Willow (Salix purpurea, "Hotel") on Soil Carbon and Nutrient Availability
# id:36 u:galm t:None i:None
# id:37 u:galm t:None i:None
# id:38 u:galm t:None i:None
# id:333 u:galm t:Afforestation/reforestation i:None
# id:334 u:galm t:Afforestation/reforestation i:None
# id:354 u:galm t:None i:None
# id:365 u:galm t:None i:None
# id:618 u:lamw t:Afforestation/reforestation i:None
# id:894 u:galm t:None i:None
# id:1088 u:rogers t:None i:None
# id:1094 u:rogers t:None i:None
# id:1098 u:rogers t:None i:None
# id:1099 u:rogers t:None i:None
# id:1103 u:rogers t:None i:None
# id:1105 u:rogers t:None i:None
# id:1106 u:rogers t:None i:None
# id:1127 u:rogers t:None i:None
# id:1128 u:rogers t:None i:None
# id:1132 u:rogers t:None i:None
# id:1134 u:rogers t:None i:None
# id:1135 u:rogers t:None i:None
# id:1176 u:rogers t:None i:None
# id:1201 u:rogers t:Afforestation/reforestation i:RD
# id:1205 u:rogers t:Afforestation/reforestation i:Demandpull
# id:1207 u:rogers t:Afforestation/reforestation i:Publicaccept
# id:1208 u:rogers t:Afforestation/reforestation i:Innovationgeneral
# id:1291 u:rogers t:None i:None
# id:1497 u:lamw t:None i:None
#
# ############
# WOS:000258823800004
# Using poultry litter biochars as soil amendments
# id:36 u:galm t:None i:None
# id:37 u:galm t:None i:None
# id:38 u:galm t:None i:None
# id:335 u:galm t:Biochar i:None
# id:336 u:galm t:Biochar i:None
# id:354 u:galm t:None i:None
# id:365 u:galm t:None i:None
# id:568 u:galm t:Biochar i:None
# id:894 u:galm t:None i:None
# id:1072 u:rogers t:None i:None
# id:1086 u:rogers t:None i:None
# id:1094 u:rogers t:None i:None
# id:1098 u:rogers t:None i:None
# id:1099 u:rogers t:None i:None
# id:1100 u:rogers t:None i:None
# id:1106 u:rogers t:None i:None
# id:1107 u:rogers t:None i:None
# id:1109 u:rogers t:None i:None
# id:1111 u:rogers t:None i:None
# id:1117 u:rogers t:None i:None
# id:1174 u:rogers t:None i:None
# id:1183 u:rogers t:None i:None
# id:1185 u:rogers t:Soil Carbon Sequestration i:RD
# id:1192 u:rogers t:Soil Carbon Sequestration i:Innovationgeneral
# id:1284 u:rogers t:None i:None
# id:1285 u:rogers t:None i:None
# id:1304 u:rogers t:None i:None
# id:1497 u:lamw t:None i:None
#
# ############
# WOS:000330814100055
# Production of microporous biochars by single-step oxidation: Effect of activation conditions on CO2 capture
# id:37 u:galm t:None i:None
# id:38 u:galm t:None i:None
# id:335 u:galm t:Biochar i:None
# id:336 u:galm t:Biochar i:None
# id:354 u:galm t:None i:None
# id:365 u:galm t:None i:None
# id:568 u:galm t:Biochar i:None
# id:894 u:galm t:None i:None
# id:1072 u:rogers t:None i:None
# id:1086 u:rogers t:None i:None
# id:1094 u:rogers t:None i:None
# id:1098 u:rogers t:None i:None
# id:1099 u:rogers t:None i:None
# id:1100 u:rogers t:None i:None
# id:1106 u:rogers t:None i:None
# id:1107 u:rogers t:None i:None
# id:1109 u:rogers t:None i:None
# id:1111 u:rogers t:None i:None
# id:1117 u:rogers t:None i:None
# id:1174 u:rogers t:None i:None
# id:1183 u:rogers t:None i:None
# id:1185 u:rogers t:Soil Carbon Sequestration i:RD
# id:1192 u:rogers t:Soil Carbon Sequestration i:Innovationgeneral
# id:1284 u:rogers t:None i:None
# id:1285 u:rogers t:None i:None
# id:1304 u:rogers t:None i:None
# id:1497 u:lamw t:None i:None
#
# ############
# WOS:000375125200011
# Greenhouse gas mitigation potentials in the livestock sector
# id:36 u:galm t:None i:None
# id:37 u:galm t:None i:None
# id:38 u:galm t:None i:None
# id:330 u:galm t:Soil Carbon Sequestration i:None
# id:354 u:galm t:None i:None
# id:365 u:galm t:None i:None
# id:894 u:galm t:None i:None
# id:1057 u:lamw t:None i:None
# id:1086 u:rogers t:None i:None
# id:1098 u:rogers t:None i:None
# id:1099 u:rogers t:None i:None
# id:1103 u:rogers t:None i:None
# id:1105 u:rogers t:None i:None
# id:1106 u:rogers t:None i:None
# id:1107 u:rogers t:None i:None
# id:1109 u:rogers t:None i:None
# id:1114 u:rogers t:None i:None
# id:1116 u:rogers t:None i:None
# id:1117 u:rogers t:None i:None
# id:1173 u:rogers t:None i:None
# id:1183 u:rogers t:None i:None
# id:1185 u:rogers t:Soil Carbon Sequestration i:RD
# id:1189 u:rogers t:Soil Carbon Sequestration i:Demandpull
# id:1191 u:rogers t:Soil Carbon Sequestration i:Publicaccept
# id:1192 u:rogers t:Soil Carbon Sequestration i:Innovationgeneral
# id:1254 u:smip t:Soil Carbon Sequestration i:None
# id:1284 u:rogers t:None i:None
# id:1304 u:rogers t:None i:None
# id:1366 u:galm t:None i:None
# id:1373 u:galm t:None i:None
# id:1457 u:galm t:None i:None
# id:1497 u:lamw t:None i:None

# %%
oweird = trdocs.difference(inrateddocs)

all_inno = set(list(Doc.objects.filter(query=1106).values_list('UT',flat=True)))

len(oweird.intersection(all_inno))

uninrated = Doc.objects.filter(UT__in=list(oweird))
q = Query.objects.get(pk=1504)
for d in uninrated:
    d.query.add(q)
    d.save()

# %%
len(trdocs.intersection(irdocs))
# Out:
# 675

# %%
allidocs = allreldocs.filter(
    docownership__relevant=5,
).values('PY','docownership__query__innovation__name').annotate(
    n = Count('pk', distinct = True)
)
df = pd.DataFrame.from_dict(list(allidocs))
df.head()
# Out:
#      PY docownership__query__innovation__name   n
# 0  2007                                    RD  21
# 1  2012                               Scaleup  20
# 2  2006                               Scaleup   6
# 3  2015                                    RD  58
# 4  2004                                    RD  11

# %%
plt.rcParams["figure.figsize"] = [12,8]

fig, axs = plt.subplots(nrows=2,ncols=3,gridspec_kw=dict(hspace=0.4))

pt = pd.pivot_table(
    df,
    values='n',
    columns=['PY'],
    index=['docownership__query__innovation__name'],
    fill_value=0
)

fullindex = pd.DatetimeIndex(freq='1A', start='1974', end='2017')

pt = (
    df.set_index(['PY','docownership__query__innovation__name'])
        .unstack(level='docownership__query__innovation__name')
        .reindex(range(1990,2018))
        .fillna(0)
        .stack()
        .reset_index()
)

print(pt.head())




grouped =  pt.groupby('docownership__query__innovation__name')

targets = zip(grouped.groups.keys(), axs.flatten())

n = 5

for i, (key, ax) in enumerate(targets):
    
    group = grouped.get_group(key)
    
    group = group.sort_values('PY')
    group = group.set_index('PY')
    group.plot.bar(ax=ax, legend=False)
    #ax.bar(group.index,group['n'])
    #ax.bar(group,group[['n']])
    
    ticks = ax.xaxis.get_ticklocs()
    ticklabels = [l.get_text() for l in ax.xaxis.get_ticklabels()]
    ax.xaxis.set_ticks(ticks[::n])
    ax.xaxis.set_ticklabels(ticklabels[::n])
    
    if key=="RD":   
        m = 100
    else:   
        m = 50
        
    ax.set_ylim(0,m)
    
    
    ax.set_title(key)
    
    s = "N = {:d}".format(int(group.sum()['n']))
    
    ax.text(1,m*0.8, s)
    

plt.savefig('plots/1_1_1.png',bbox_inches='tight') 
plt.show()
# Out:
#      PY docownership__query__innovation__name    n
# 0  1990                            Demandpull  0.0
# 1  1990                                 Demos  0.0
# 2  1990                          Nichemarkets  0.0
# 3  1990                          Publicaccept  0.0
# 4  1990                                    RD  0.0

# %%
# Out:
# 339.0

# %%
allds = allreldocs.filter(
    docownership__relevant__in=[5,1],
).values(
    'docownership__query__innovation__name',
    'docownership__query__technology__name',
    'PY'
).annotate(
    n = Count('pk', distinct = True)
)
lallds = list(allds)
lallds.append({
    "PY":1990,
    "docownership__query__innovation__name": "Scaleup",
    "docownership__query__technology__name": "Afforestation/reforestation",
    "n": 0
})
adf = pd.DataFrame.from_dict(lallds)
adf = adf[adf['docownership__query__innovation__name'] != "None"]
adf.sort_values('PY').head()
# Out:
#        PY docownership__query__innovation__name  \
# 397  1990                               Scaleup
# 231  1991                               Scaleup
# 295  1991                                  None
# 329  1991                                    RD
# 96   1992                                  None
#
#     docownership__query__technology__name  n
# 397           Afforestation/reforestation  0
# 231           Afforestation/reforestation  1
# 295           Afforestation/reforestation  2
# 329           Afforestation/reforestation  2
# 96            Afforestation/reforestation  2

# %%
reindexes = [
    ('PY','docownership__query__technology__name','docownership__query__innovation__name'),
    ('PY','docownership__query__innovation__name','docownership__query__technology__name'),
    ('docownership__query__innovation__name','docownership__query__technology__name','PY')
]

pt = adf

for x in reindexes:

    pt = pd.pivot_table(
        pt,
        values='n',
        columns=[x[2]],
        index=[x[0],x[1]],
        fill_value=0
    ).reset_index()


    pt = pd.melt(
        pt,
        id_vars=[x[0],x[1]],
        value_name='n'
    ).reset_index()

pt['docownership__query__innovation__name']

# %%
groupings = [
    ('docownership__query__innovation__name','docownership__query__technology__name',2),
    ('docownership__query__technology__name','docownership__query__innovation__name',3),
]


for x in groupings:
    
    plt.rcParams["figure.figsize"] = [12,4*x[2]]
    
    grouped = pt.groupby(x[0])

    fig, axs = plt.subplots(nrows=x[2],ncols=3,gridspec_kw=dict(hspace=0.4))
    targets = zip(grouped.groups.keys(), axs.flatten())

    for i, (key, ax) in enumerate(targets):
        try:
            group = grouped.get_group(key)
            group = group.sort_values('PY')

            table = pd.pivot_table(
                group,
                values='n',
                columns=[x[1]],
                index=['PY']
            )

            table.plot.bar(ax=ax,stacked=True,legend=False,title=key)
            
            l = ax.legend()

            if i == 0:
                ax.legend()
            
            ticks = ax.xaxis.get_ticklocs()
            ticklabels = [l.get_text() for l in ax.xaxis.get_ticklabels()]
            ax.xaxis.set_ticks(ticks[::n])
            ax.xaxis.set_ticklabels(ticklabels[::n])
            
            if key=="RD":   
                m = 100
            else:   
                m = 50
        
            ax.set_ylim(0,m)
            
        except:
            print(key)
            print(group)
            pass

    #plt.legend()
    #fig.legend()
    plt.savefig('plots/1_1_{}.png'.format(x[2]),bbox_inches='tight') 
    plt.show()

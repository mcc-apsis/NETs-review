# %%
import django, os, sys, time, resource, re, gc, shutil
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from django.db.models import Count, Avg, F, Sum
import math

sys.path.append('/home/galm/software/django/tmv/BasicBrowser/')

os.environ.setdefault("DJANGO_SETTINGS_MODULE", "BasicBrowser.settings")
django.setup()

from scoping.models import *
from utils.utils import *

# %%
alldocs = Doc.objects.filter(
    query__project=2,
    query__qtype='MN',
    query__upload_link__category__project=2,
    query__upload_link__category__gt=0,
    wosarticle__ti__isnull=False
)

print(alldocs.count())

for d in alldocs:
    d.uploaded=True
    d.save()

pdoc_ids = Doc.objects.filter(query__project=2,uploaded=False).values_list('id',flat=True)

pdocs = Doc.objects.filter(id__in=list(set(list(pdoc_ids))))

print(pdocs.count())
# Out:
# 422
# 97354

# %%
found = 0
for d in alldocs:
    ti = d.wosarticle.ti.replace('\r','').replace('\n','').strip()
    print(repr(ti))
    sdocs = pdocs.filter(
        title=ti
    ).exclude(id=d.id)
    if sdocs.count() == 1:
        rdoc = sdocs.first()
        for q in d.query.all():
            rdoc.query.add(q)
            
        if hasattr(d,'docfile'):
            df = d.docfile
            df.doc = rdoc
            df.save()
        rdoc.save()
        d.delete()  
        print("attached to {}".format(rdoc.UT) )
        
print("FOUND {} docs in database".format(found))
# Out:
# 'Sustainable  biochar  to  mitigate  global climate  change'
# 'Atmospheric CO2 capture by algae: Negative carbon dioxide emission path'
# 'COP21: The algae opportunity?'
# 'Carbon capture and storage, bio-energy with carbon capture and storage, and theescape from the fossil-fuel lock-in'
# 'The economic potential of bioenergy for climate change mitigation with special attention given to implications for the land system'
# 'Afforestation to mitigate climate change: impacts on food prices under consideration of albedo effects'
# 'Trade-offs between land and water requirements for large-scale bioenergy production'
# 'Land-use transition for bioenergy and climate stabilization:model comparison of drivers, impacts and interactionswith other land use based mitigation options'
# 'Additional CO2 emissions from land use change — Forest conservation as aprecondition for sustainable production of second generation bioenergy'
# 'Biojet fuels and emissions mitigation in aviation: An integratedassessment modeling analysis'
# 'The future role of CCS in electricity and liquid fuel supply'
# 'Carbon capture and storage across fuels and sectors in energy systemtransformation pathways'
# 'Energy modeling approach to the global energy-mineral nexus: A first look at metal requirements and the 2 °C target'
# 'Time-integrated GHG emissions in advanced waste-to-energy plants producing fuels, chemicals and electricity from MSW refuse'
# 'Time-integrated GHG emissions in advanced waste-to-energy plants producing fuels, chemicals and electricity from MSW refuse'
# 'Proving the climate benefit in the production of biofuels frommunicipal solid waste refuse in Europe'
# 'Optimal scale of carbon-negative energy facilities'
# 'Biomass enables the transition to a carbon negativepower system across westernNorth America'
# 'Carbon-negative emissions: Systemic impacts of biomass conversion A case study on CO2capture and storage options'
# 'Afforestation to mitigate climate change: impacts on food prices under consideration of albedo effects'
# 'Land-use transition for bioenergy and climate stabilization:model comparison of drivers, impacts and interactionswith other land use based mitigation options'
# 'Does seaweed offer a solution for bioenergy with biological carbon capture and storage?'
# 'Inefficient power generation as an optimal route to negative emissions via BECCS?'
# 'Potential and cost-effectiveness of CO2 reductions throughenergy measures in Swedish pulp and paper mills'
# 'Potential and cost-effectiveness of CO2 reductions throughenergy measures in Swedish pulp and paper mills'
# 'Potential and cost-effectiveness of CO2 reductions throughenergy measures in Swedish pulp and paper mills'
# 'CO2 CAPTURE IN PULP AND PAPER MILLS: CO2 BALANCESAND PRELIMINARY COST ASSESSMENT'
# 'CO2 CAPTURE IN PULP AND PAPER MILLS: CO2 BALANCESAND PRELIMINARY COST ASSESSMENT'
# 'A life cycle assessment approach to quantifying greenhouse gas emissions from land-use change for beef production in eastern Australia'
# 'THE DEPTH DISTRIBUTION OF SOIL ORGANIC CARBON IN RELATION TO LAND USE AND MANAGEMENT AND THE POTENTIAL OF CARBON SEQUESTRATION IN SUBSOIL HORIZONS'
# 'Strengthening the soil organic carbon pool by increasing contributions from recalcitrant aliphatic bio(macro)molecules'
# 'Water Footprint and Land Requirement of Solar Thermochemical Jet-Fuel Production'
# 'Microbial Electrolytic Carbon Capture for Carbon Negative and Energy Positive Wastewater Treatment'
# 'Self-sustaining carbon capture and mineralization via electrolytic carbonation of coal fly ash'
# 'Ambient CO2 capture and storage in bioelectrochemically mediated wastewater treatment'
# 'https://doi.org/10.1016/j.energy.2005.09.014'
# 'Pyrolysis bioenergy with biochar production – greater carbon abatement and benefits to soil'
# 'https://doi.org/10.1016/j.cej.2008.06.005'
# 'Influence of production conditions on the yield and environmental stability of biochar.'
# 'A review of biochar and its use and function in soil'
# 'Australian climate–carbon cycle feedback reduced by soil black carbon. Nature Geoscience 1:832-835'
# 'Afforestation of black spruce lichen woodlands by natural seeding'
# 'Afforestation of Boreal Open Woodlands: Early Performance and Ecophysiology of Planted Black Spruce Seedlings'
# 'Black spruce growth and survival in boreal open woodlands 10 years following mechanical site preparation and planting'
# 'Black-spruce-lichen woodlands growth and carbon drawdown potentials as revealed by mature stands'
# 'Biochar and manure alter few aspects of prairie development: A field test'
# 'Forests, climate, and public policy: A 500-year interdisciplinary odyssey'
# 'Modeling the impact of carbon farming on land use in a New Zealand landscape'
# 'Climate Strategy with Co2 Capture from the Air'
# 'Spontaneous Cooling Absorption of CO2 by a Polymeric Ionic Liquid for Direct Air Capture'
# 'Integrated direct air capture and CO2 utilization of gas fertilizer based on moisture swing adsorption'
# 'Designing Moisture-Swing CO2 Sorbents through Anion Screening of Polymeric Ionic Liquids'
# 'Fighting global warming by greenhouse gas removal: destroying atmospheric nitrous oxide thanks to synergies between two breakthrough technologies'
# 'Removal of non-CO2 greenhouse gases by large-scale atmospheric solar photocatalysis'
# 'Fighting global warming by GHG removal: Destroying CFCs and HCFCs in solar-wind power plant hybrids producing renewable energy with no-intermittency.'
# 'Climate engineering by mimicking natural dust climate control: the iron salt aerosol method.'
# 'Geo-Engineering: sunlight reflection methods and negative emissionstechnologies for greenhouse gas removal'
# 'One-pot sol–gel synthesis of amine hybrid titania/silsesquioxane composite aerogel for CO2 capture'
# 'Amine hybrid zirconia/silica composite aerogel for low-concentration CO 2 capture'
# 'Development of monolithic adsorbent via polymeric sol-gel process for low-concentration CO2 capture'
# 'A new aerogel based CO2 adsorbent developed using a simple sol–gel method along with supercritical drying'
# 'Use of one-pot wet gel or precursor preparation and supercritical drying procedure for development of a high-performance CO2 sorbent'
# 'Use of monolithic silicon carbide aerogel as a reusable support for development of regenerable CO2 adsorbent'
# 'Supercritical drying: A promising technique on synthesis of sorbent for CO2 capture'
# 'Marine microalgae: Climate, energy, and food security from the sea.'
# 'The Production of Engineered Biochars in a Vertical Auger Pyrolysis Reactor for Carbon Sequestration'
# 'Biochar Classification System and Associated Test Methods.'
# 'Biochar properties: Transport, fate, and impact'
# 'Forest transitions, trade, and the globaldisplacement of land use'
# 'Estimating the world’s potentially available cropland using abottom-up approach'
# 'Land management and land-cover changehave impacts of similar magnitude onsurface temperature'
# 'Drivers, constraints and trade-offs associated with recultivatingabandoned cropland in Russia, Ukraine and Kazakhstan'
# 'Land management: data availability and processunderstanding for global change studies'
# 'Multiple pathways of commodity cropexpansion in tropical forest landscapes'
# 'Trends in Global Land-Use Competition'
# 'Soil properties, greenhouse gas emissions and crop yield under compost, biochar and co-composted biochar in two tropical agronomic systems'
# 'Hydrochar enhances growth of poplar for bioenergy while marginally contributing to direct soil carbon sequestration'
# 'Using the Suess effect on the stable carbon isotope to distinguish the future from the past in radiocarbon'
# 'The next generation of iron fertilization experiments in the Southern Ocean.'
# 'The next generation of iron fertilisation experiments in the Southern Ocean'
# 'Life Cycle Assessment of Carbon Dioxide–Based Production of Methane and Methanol and Derived Polymers'
# 'Food, fuel and climate change: Is palm-based biodiesel a sustainable option for Thailand?'
# 'Reducing greenhouse gas emissions in agriculture without compromising food security?'
# 'Consequential and attributional environmental assessment of biofuels: Implications of modelling choices on climate change mitigation strategies'
# 'Range and uncertainties in estimating delays in greenhouse gas mitigation potential of forest bioenergy sourced from Canadian forests'
# 'A Tree Species Effect on Soil That Is Consistent Across the Species’ Range: The Case of Aspen and Soil Carbon in North America'
# 'N-use efficiencies and N2O emissions in two contrasting, biochar amended soils under winter wheat - cover crop - sorghum rotation'
# 'Response of the protozooplankton assemblage during the European Iron Fertilization Experiment (EIFEX) in the Antarctic circumpolar current'
# 'A grassland strategy for farming systems in Europe to mitigate GHG emissions—An integrated spatially differentiated modelling approach'
# 'Progressive decoupling between phytoplankton growth and microzooplankton grazing during an iron-induced phytoplankton bloom in the Southern Ocean (EIFEX'
# 'Long-term farming systems research in the central High Plainshttps://www.cambridge.org/core/journals/renewable-agriculture-and-food-systems/article/long-term-farming-systems-research-in-the-central-high-plains/E2A0FE9B9726B8581740A00B014DCD24'
# 'Climate change impacts of power generation from residual biomass'
# 'A grassland strategy for farming systems in Europe to mitigate GHG emissions—An integrated spatially differentiated modelling approach'
# 'An energy-biochar chain involving biomass gasification and rice cultivation in Northern Italy'
# 'Data synthesis of carbon distribution in particle size fractions of tropical soils: Implications for soil carbon storage potential in croplands'
# 'Geoengineering and International Law'
# 'International Liability for Transboundary Damage Arising from Stratospheric Aerosol Injections'
# 'EnvHaddaway N.R., Hedlund K., Jackson L.E., Kätterer T., Lugato E., Thomsen I.K., Bracht Jørgensen H., Söderström B. 2015. What are the effects of agricultural management on soil organic carbon in boreo-temperate systems? A systematic map.'
# 'Strategies for carbon sequestration in agricultural soils in northern Europe.'
# 'Poeplau C., Bolinder M.A., Eriksson J., Lundblad M., Kätterer T. 2015. Positive trends in organic carbon storage in Swedish agricultural soils due to unexpected socio-economic drivers'
# 'Ecosystem function and service quantification and valuation in a conventional winter wheat production system with DAISY model in Denmark'
# 'Reducing losses but failing to sequester carbon in soils – the case of Conservation Agriculture and Integrated Soil Fertility Management in the humid tropical agro-ecosystem of Western Kenya'
# 'Global Sequestration Potential of Increased Organic Carbon in Cropland'
# 'Kirschbaum, M.U.F., Saggar, S., Tate, K.R., Giltrap, D.L., Ausseil, A.G.E., Greenhalgh, S., Whitehead, D. (2012). Comprehensive evaluation of the implications of shifting land use between forest and grassland. Agriculture,'
# 'Kirschbaum, M.U.F. (2014). Climate Change Impact Potentials as an alternative to Global Warming Potentials.'
# 'Kirschbaum, M.U.F. (2017). Assessing the merits of bioenergy by estimation marginal climate-change impacts. The International Journal of Life Cycle Assessment'
# 'Kirschbaum MUF, Whitehead D, Dean SM, Beets PN, Shepherd JD, Ausseil AGE (2011). Implications of changes in albedo on the benefits of forests as carbon sinks.'
# 'Kirschbaum, M.U.F., Saggar, S., Tate, K.R., Thakur, K., Giltrap, D. (2013). Quantifying the climate-change consequences of shifting land use between forest and agriculture.'
# 'Kirschbaum MUF, Schipper LA, Mudge PL, Rutledge S, Puche NJB, Campbell DI (2017). The trade-offs between milk production and soil organic carbon storage in dairy systems under different management and environmental factors.'
# 'Atmospheric CO2 sink: Silicate weathering or carbonate weathering?'
# 'Soil aggregation and organic carbon fractions affected by long-term fertilization in ared soil of subtropical China'
# 'Significance of the carbon sink produced by H2O-carbonate-CO2-aquatic phototroph interaction on land'
# 'Organic carbon fractions affected by long-term fertilizationin a subtropical paddy soil'
# 'Hydrologically-driven variations in the karst-related carbon sink fluxes: Insights from high-resolution monitoring of three karst catchments in Southwest China'
# 'Carbonate weathering-related carbon sink fluxes under different land uses: A case study from the Shawan Simulation Test Site, Puding, Southwest China'
# 'Biochar helps enhance maize productivity and reduces greenhouse gas emissions under balanced fertilization in a rained low fertility inceptisol'
# "Projected changes in soil organic carbon stocks of China's croplands under different agricultural managements, 2011–2050"
# 'Soil carbon efflux and sequestration as a function of relative availability of inorganic N pools in dry tropical agroecosystem'
# 'Coupled control of land uses and aquatic biological processes on the diurnal hydrochemical variations in the five ponds at the Shawan Karst Test Site, China: Implications for the carbonate weathering-related carbon sink'
# 'On our rapidly shrinking capacity to comply with the planetary boundaries on climate change'
# 'Impact of deep-ocean carbon sequestration on atmospheric CO2 and on surface-water chemistry'
# 'Time-dependent climate impact and energy efficiency of combined heat and power production from short-rotation coppice willow using pyrolysis or direct combustion'
# 'Suppressing methane emission and global warmingpotential from rice fields through intermittent drainage andgreen biomass amendment'
# 'Mitigating the Atmospheric CO2 Increase and Ocean Acidification by Adding Limestone Powder to Upwelling Regions'
# 'Climate impact and energy efficiency from electricity generation through anaerobic digestion or direct combustion of short rotation coppice willow'
# 'Global warming as affected by incorporation of variablyaged biomass of hairy vetch for rice cultivation'
# 'Climate Impact of Willow Grown for Bioenergy in Sweden'
# 'Contribution of greenhouse gas emissions during croppingand fallow seasons on total global warming potentialin mono-rice paddy soils'
# 'Comparison of net global warming potential between continuousflooding and midseason drainage in monsoon region paddy duringrice cropping'
# 'Direct air capture of CO2 and climate stabilization: A model based assessment'
# 'Optimization of removal and recycling ratio of cover crop biomassusing carbon balance to sustain soil organic carbon stocks in amono-rice paddy system'
# 'Challenges and Opportunities for Integrated Modeling of Climate Engineering'
# 'Comparison of net global warming potential between continuousflooding and midseason drainage in monsoon region paddy duringrice cropping'
# 'Contribution of greenhouse gas emissions during croppingand fallow seasons on total global warming potentialin mono-rice paddy soils'
# 'The urgency of the development of CO2 capture from ambient air'
# attached to UT object
# 'Effect of light supply on CO2 capture from atmosphere by Chlorella vulgaris and Pseudokirchneriella subcapitata'
# 'COP21: The algae opportunity?'
# 'Long-Term Effects of Sulfur and Zinc Fertilizationon Rice Productivity and Nutrient Efficiency inDouble Rice Cropping Paddy in Bangladesh'
# 'Optimum application level of winter cover crop biomassas green manure under considering methane emissionand rice productivity in paddy soil'
# 'Economic evaluation of biomass-based energy systems with CO2 capture and sequestration in kraft pulp mills- The influence of the price of co2 emission quota'
# 'Controls on CO2 storage security in natural reservoirs and implications for CO2 storage site selectionMiocic, J., Gilfillan, S., Roberts, J. J., Edlmann, K., McDermott, C. & Haszeldine, R. 1 Aug 2016 In : International Journal of Greenhouse Gas Control. 51, p. 118-125'
# 'Investment under Multiple Uncertainties:The Case of Future Pulp and Paper Mills'
# 'The urgency of the development of CO2 capture from ambient air'
# attached to UT object
# 'A CROSS-MODEL COMPARISON OF GLOBAL LONG-TERM TECHNOLOGY DIFFUSION UNDER A 2°C CLIMATE CHANGE CONTROL TARGET'
# 'Offshore CCS and ocean acidification: a global long-term probabilistic cost-benefit analysis of climate change mitigation'
# 'A framework coupling farm typology and biophysical modelling to assess the impact of vegetable crop-based systems on soil carbon stocks. Application in the Caribbean'
# 'Observed and predicted changes in soil carbon stocks under export and diversified agriculture in the Caribbean. The case study of Guadeloupe'
# 'Integrated Mineral Carbonation Reactor Technology for Sustainable Carbon Dioxide Sequestration: ‘CO2 Energy Reactor’'
# 'The Carbon Dioxide Removal Model Intercomparison Project (CDR-MIP): Rationale and experimental design'
# 'Global Sequestration Potential of Increased Organic Carbon in Cropland'
# 'Global Tree Cover and Biomass Carbon on Agricultural Land: The contribution of agroforestry to global and national carbon budgets'
# 'Environmental and economic impacts of agri-environmental schemesdesigned in French West Indies to enhance soil C sequestration andreduce pollution risks. A modelling approach'
# 'Global Sequestration Potential of Increased Organic Carbon in Cropland'
# 'Challenges and future directions in urbanafforestation'
# 'Natural climate solutions'
# 'Quantifying Greenhouse Gas Emissions from Agricultural and Forest Landscapes for Policy Development and Verification'
# 'Land Quality and Management Practices Strongly Affect Greenhouse Gas Emissions of Bioenergy Feedstocks'
# 'Australian climate–carbon cycle feedback reduced by soil black carbon'
# 'Carbon sequestration in the U.S. forest sector from 1990 to 2010'
# 'Task  Force  on  RD&D  strategy  for  CO2 Utilization  and/or Negative Emissions at the gigatonne scale'
# 'DOE Assessment of the SEAB CO2 Utilization Report'
# 'Opinion: Quantum solutions for a sustainable energy future'
# 'Applicability of linear polyethylenimine supported on nano-silica for the adsorption of CO2 from various sources including dry air'
# 'Applicability of linear polyethylenimine supported on nano-silica for the adsorption of CO2 from various sources including dry air'
# 'Recycling of carbon dioxide to methanol and derived products – closing the loop'
# 'Dynamics of soil aggregate-associated organic carbon along an afforestation chronosequence'
# 'Human Rights Dimensions of Bioenergy With Carbon Capture and Storage:A Framework for Climate Justice in the Realm of Climate Geoengineering'
# 'The Carbon Dioxide Removal Model Intercomparison Project (CDR-MIP): Rationale and experimental design'
# 'Geoengineering the oceans: an emerging frontier in international climate change governance'
# 'Simulating the Earth system response to negative emissions'
# attached to UT object
# 'Bioenergy and carbon capture with storage (BECCS): the prospects and challenges of an emerging climate policy response'
# 'THE PARIS AGREEMENT AND CLIMATEGEOENGINEERING GOVERNANCETHE NEED FOR A HUMAN RIGHTS-BASED COMPONENT'
# 'The Carbon Dioxide Removal Model Intercomparison Project (CDR-MIP): Rationale and experimental design'
# 'Greenhouse Gas Property: An Adaptable Climate Policy for an Uncertain World'
# 'Aboveground live carbon stock changes of California wildland ecosystems, 2001–2010'
# 'Effect of grazing on carbon sequestration and tree growth that isdeveloped in a silvopastoral system under wild cherry (Prunus avium L.)'
# 'Effect of liming and organic and inorganic fertilization on soil carbonsequestered in macro-and microaggregates in a 17-year old Pinusradiata silvopastoral system'
# 'Economic Assessment of Carbon Capture and Storage Facilities Coupled to Coal-fired Power Plants'
# 'Carbon dioxide storage schemes: Technology, assessment anddeployment'
# 'Cost-effectiveness analysis of algae energy production in the EU'
# 'Energy and greenhouse gas balances of cassava-based ethanol'
# 'Solar thermal decomposition of desalination reject brine for carbon dioxide removal and neutralisation of ocean acidity'
# 'Desalination as a Negative Emissions Technology'
# 'Solar thermal decomposition of desalination reject brine for carbon dioxide removal and neutralisation of ocean acidity'
# 'Accumulation of soil organic carbon in aggregatesafter afforestation on abandoned farmland'
# 'The Accumulation of Organic Carbon in Mineral Soils byAfforestation of Abandoned Farmland'
# 'Ecosystem Carbon and Nitrogen Accumulation afterGrazing Exclusion in Semiarid Grassland'
# 'Changes in soil organic carbon and total nitrogen after 28 yearsgrassland afforestation: effects of tree species,slope position, and soil order'
# 'Embedding CCS infrastructure into the European electricity system: a policy coordination problem'
# 'A Very Inconvenient Truth'
# attached to UT object
# 'Ocean Iron Fertilization Experiments: Past–Present–Future with Introduction to Korean Iron Fertilization Experiment in the Southern Ocean (KIFES) Project'
# 'Geoengineering,marinemicroalgae, and climatestabilization in the 21st century'
# 'Geoengineering:The Inescapable Truth ofGetting to 350'
# 'Effect of biochar and liming on soil nitrous oxideemissions from a temperate maize cropping system'
# 'Carbon sequestration via wood burial'
# attached to UT object
# 'Quantifying geological CO2 storage security to deliver on climate mitigation'
# 'The Potential Role of Biochar in Combating Climate Change in Scotland: An Analysis of Feedstocks, Life Cycle Assessment and Spatial Dimensions'
# 'Storing carbon for geologically long timescales to engineer climate'
# attached to UT object
# 'Last chance for carbon capture and storage'
# 'Biochar, Tool for Climate Change Mitigation and Soil Management'
# 'Fossil fuels in a trillion tonne world'
# attached to UT object
# 'Assessing the health risks of natural CO2 seeps in Italy'
# 'Biophysical potential for soil carbon sequestration in agricultural systems of the Old Peanut Basin of Senegal'
# attached to UT object
# 'Retrospective and prospective dynamics of soil carbon sequestration in Sahelian agrosystems in Senegal'
# attached to UT object
# 'Soil responses to bioenergy crop production in the North Carolina Piedmont'
# 'Greenhouse gas emissions in an agroforestry system of the southeastern USA'
# 'MAGGnet: An international network to foster mitigation of agricultural greenhouse gases'
# 'Carbon dioxide storage schemes: Technology, assessment and deployment'
# 'Model-based Assessment of the CO2 Sequestration Potential of Coastal Ocean Alkalinization'
# 'Biosolids amendment dramatically increases sequestration of crop residue-carbon in agricultural soils in western Illinois'
# 'Temporal Dynamics of Total and Particulate Organic Carbon and Nitrogen in Cover Crop Grazed Cropping Systems'
# attached to UT object
# 'Agronomic and environmental impacts of pasture–crop rotations in temperate North and South America'
# 'Agronomic and environmental impacts of pasture–crop rotations in temperate North and South America'
# 'Brief Summary of MarineGeoengineering Techniques'
# 'Agronomic and environmental impacts of pasture–crop rotations in temperate North and South America'
# 'Agronomic and environmental impacts of pasture–crop rotations in temperate North and South America'
# 'Nuclear carbonization and gasification of biomass for effective removalof atmospheric CO2'
# 'Crop and cattle production responses to tillage and cover crop management in an integrated crop–livestock system in the southeastern USA'
# 'Executive SummaryCARBON-NEGATIVE ENERGY SYSTEM*Sustainable World Energy Supply and Global Environment RestorationUsing Renewable and Nuclear Energies'
# 'Evaluating soil organic carbon sequestration potential in the Cotton Belt with the soil conditioning index'
# 'Tall Fescue Management in the Piedmont: Sequestration of Soil Organic Carbon and Total Nitrogen'
# 'Carbonate precipitation in artificial soils as a sink for atmospheric carbon dioxide'
# attached to UT object
# 'Investigating carbonate formation in urban soils as a method for capture and storage of atmospheric carbon'
# attached to UT object
# 'Engineering challenges of ocean liming'
# attached to UT object
# 'Coupling Mineral Carbonation and Ocean Liming'
# attached to UT object
# 'Assessing ocean alkalinity for carbon sequestration'
# attached to UT object
# 'Rapid Removal of Atmospheric CO2 by Urban Soils'
# attached to UT object
# 'Moral Turbulence and Geoengineering: A Lingering Hazard from the Perfect Moral Storm'
# 'Assessing the impact of management practices on gas emissions and N losses calculated with denitrification-decomposition model'
# 'Modeling Impact of Climate Changeand Management Practices on GreenhouseGas Emissions from Arable Soils'
# 'Biomass combustion with CO2 capture by chemical looping with oxygen uncoupling (CLOU)'
# attached to UT object
# 'Combustion and Reforming of Ethanol in a Chemical Looping Continuous Unit'
# 'Optimization of hydrogen production with CO2 capture by autothermal chemical-looping reforming using different bioethanol purities'
# 'Bioethanol combustion with CO2 capture in a 1 kWth Chemical Looping Combustion prototype: Suitability of the oxygen carrier'
# 'Chemical Looping Combustion of different types of biomass in a 0.5 kWth unit'
# 'Chemical looping combustion of biomass: CLOU experiments with a Cu-Mnmixed oxide'
# 'Impact of Biochar Formulation on the Release of Particulate Matter and on Short-Term Agronomic Performance'
# 'Black Carbon aerosol from biochar threats its negative emission potential'
# 'Biochar–macrofauna interplay: Searching for new bioindicators'
# 'An energy‐biochar chain involving biomass gasification and rice cultivation in Northern Italy'
# 'Field application of pelletized biochar: Short term effect on the hydrological properties of a silty clay loam soil'
# 'Land use change and soil organic carbon dynamics in Mediterranean agro-ecosystems: the case study of Pianosa Island'
# 'Comparing integrated stable isotope and eddy covariance estimates of water-use efficiency on a Mediterranean successional sequence'
# attached to UT object
# 'Gaiser, T., Stahr, K., Bernard, M. & Kang, B. (2012). Changes in soil organic carbon fractions in a tropical Acrisol as influenced by the addition of different residue materials. Agroforestry Systems: 1-11.'
# 'Modeling carbon sequestration under zero-tillage at the regional scale. II. The influence of crop rotation and soil type. Ecological Modelling 220(23): 3372-3379.'
# 'Carbon sequestration in soils of SW-Germany as affected by agricultural management-Calibration of the EPIC model for regional simulations'
# attached to UT object
# 'Afforestation of agricultural land with spotted gum (Corymbia citriodora)increases soil carbon and nitrogen in a Ferrosol'
# 'Comparing and predicting soil carbon quantities under different land-use systems on the Red Ferrosol soils of southeast Queensland'
# attached to UT object
# 'Biochar: maximising the benefits'
# 'A review of research on forest-related environmental markets (including certification schemes, bioenergy, carbon markets and other ecosystem services)'
# 'Towards a faster and broader application of biochar: appropriate marketing mechanisms'
# 'Economic consequences of consideration of permanence, leakage and additionality for soil carbon sequestration projects'
# 'Forest Biomass Supply in the Southeastern United States - Implications for Industrial Roundwood and Bioenergy Production'
# 'Iron Fertilization in the Ocean for Climate Mitigation: Legal, Economic, and Environmental Challenges'
# 'Effects of land use change on soil carbon cycling in the conterminous United States from 1900 to 2050'
# attached to UT object
# 'Australian climate–carbon cycle feedback reduced by soil black carbon'
# 'Land Quality and Management Practices Strongly Affect Greenhouse Gas Emissions of Bioenergy Feedstocks'
# 'Methane and nitrous oxide emissions under no-till farming in China: A meta-analysis'
# 'CQESTR Simulation of Dryland Agroecosystem Soil Organic Carbon Changes under Climate Change Scenarios'
# 'The effect of no-till on organic C storage in Chinese soils should not be overemphasized: A meta-analysis'
# attached to UT object
# 'Integrated Assessment of Carbon Capture and Storage (CCS) in South Africa’s Power Sector'
# 'Prospects of carbon capture and storage (CCS) in China’s power sector – An integrated assessment'
# 'Prospects of carbon capture and storage (CCS) in India’s power sector – An integrated assessment'
# 'Integrated assessment of carbon capture and storage (CCS) in the German power sector and comparison with the deployment of renewable energies'
# 'Nuclear carbonization and gasification of biomass for effective removalof atmospheric CO2'
# 'CARBON-NEGATIVE ENERGY SYSTEM -- Sustainable World Energy Supply and Global Environment Restoration Using Renewable and Nuclear Energies'
# 'CARBON-NEGATIVE ENERGY SYSTEM -- Sustainable World Energy Supply and Global Environment Restoration Using Renewable and Nuclear Energies'
# 'Nuclear carbonization and gasification of biomass for effective removalof atmospheric CO2'
# 'Negative CO2 emissions via enhanced silicate weathering in coastal environments'
# attached to UT object
# 'Olivine Dissolution in Seawater: Implications for CO2 Sequestration through Enhanced Weathering in Coastal Environments'
# attached to UT object
# 'Sustainable Conversion of Carbon Dioxide: An Integrated Review of Catalysis and Life Cycle Assessment'
# 'Proposals for a consortiumto implement ClimateRestoration'
# 'The role for an integrated climate restoration strategy; the setting of targets and timescales; the methodologies and funding options'
# 'Impact of the 2 °C target on global woody biomass use'
# 'Is extensive terrestrial carbon dioxide removal a ‘green’ form of geoengineering? A global modelling study'
# 'Improving regional soil carbon inventories: Combining the IPCC carbon inventory method with regression kriging'
# attached to UT object
# 'Miscanthus biomass productivity within US croplands and its potential impact on soil organic carbon'
# 'Feasibility analysis and trial of air-lift artificial upwelling powered by hybridenergy system'
# 'Hydrodynamic design of deep ocean water discharge for the creation of a nutrient-rich plume in the South China Sea'
# 'Trade-offs of different land and bioenergy policies on the path to achieving climate targets'
# attached to UT object
# 'Experimental study on the performance of an air-lift pump for artificial upwelling'
# 'Evaluation of the sinks and sources of atmospheric CO2 by artificial upwelling'
# attached to UT object
# 'Research progress in artificial upwelling and its potential environmental effects'
# attached to UT object
# 'Integrated Assessment of Carbon Capture and Storage (CCS) in South Africa’s Power Sector'
# 'Managing soil carbon for climate change mitigation and adaptation in Mediterranean cropping systems: A meta-analysis'
# 'Greenhouse gas emissions from conventional and organic cropping systems in Spain. I. Herbaceous crops'
# 'A historical perspective on soil organic carbon in Mediterranean cropland (Spain, 1900–2008)'
# 'Mitigation and quantification of greenhouse gas emissions in Mediterranean cropping systems'
# 'Mitigation and quantification of greenhouse gas emissions in Mediterranean cropping systems'
# 'Strategies for greenhouse gas emissions mitigation in Mediterranean agriculture: A review'
# attached to UT object
# 'Reduced nitrous oxide emissions and increased yields in Californiatomato cropping systems under drip irrigation and fertigation'
# 'Biochar for climate change mitigation:Navigating from science to evidence-based policy'
# 'A Tree Species Effect on Soil That Is Consistent Across the Species’ Range: The Case of Aspen and Soil Carbon in North America'
# 'Can Carbon Fluxes Explain Differences in Soil Organic Carbon Storage under Aspen and Conifer Forest Overstories?'
# 'The Use of Direct Ocean Capture and Conversion of Carbon Technologies in Support of the United Nations’ List of Sustainable Development Goals.'
# 'Estimating water–food–ecosystem trade-oﬀs for the global negative emission scenario (IPCC-RCP2.6)'
# 'Enhancing the Ocean’s Role in CO2Mitigation'
# 'Direct electrolytic dissolution of silicate minerals for airCO2 mitigation and carbon-negative H2 production'
# 'CO2 Mitigation via Capture andChemical Conversion in Seawater'
# 'Reversing ExcessAtmospheric CO2'
# 'Emissions reductionis not enough'
# 'The Global Potential for Converting Renewable Electricity to Negative-CO2-Emissions Hydrogen'
# 'Carbon Dioxide Removal: Size Matters'
# 'Combustion of eucalyptus charcoals and coals of similar volatile yields aiming at blast furnace injection in a CO2 mitigation environment'
# attached to UT object
# 'Effect of charcoal blending with a vitrinite rich coking coal on coke reactivity'
# 'Integrating physicochemical information to follow the transformations of biomass upon torrefaction and low-temperature carbonization'
# 'High organic inputs explain shallow and deep SOC storage in a long-term agroforestry system – Combining experimental and modeling approaches'
# 'Growing woody biomass for bioenergy in a tree-based intercropping system in southern Ontario, Canada'
# 'Unexpectedly large impact of forest managementand grazing on global vegetation biomass'
# 'Exploring the biophysical option space for feeding the world without deforestation.'
# 'Biomass turnover time in terrestrial ecosystems halved by land use'
# 'Erb, Karl-Heinz, Andreas Mayer, Fridolin Krausmann, Christian Lauk, Christoph Plutzar, Julia Steinberger, Helmut Haberl, 2012. The interrelations of future global bioenergy potentials, food demand and agricultural technology. In: Gasparatos, Alexandros and Per Stromberg (eds.). Socioeconomic and environmental impacts of biofuels: Evidence from developing nations. Cambridge University Press, Cambridge, 27-52.'
# 'Bioenergy: how much can we expect for 2050?'
# 'Systemic Feedbacks in Global Land Use'
# 'Competition for land: A sociometabolic perspective'
# 'Retrospective satellite ocean color analysis of purposeful and natural ocean iron fertilization'
# 'Comparative analysis of geo-engineering approaches to climate stabilization'
# attached to UT object
# 'Ocean fertilization: time to move on'
# attached to UT object
# 'Ocean Fertilization: Science, Policy, and Commerce'
# 'Implications of large-scale iron fertilization of the oceans'
# 'Ocean Iron Fertilization--Moving Forward in a Sea of Uncertainty'
# 'Predicting and verifying the intended andunintended consequences of large-scale ocean iron fertilization'
# 'Ocean fertilization and other climate changemitigation strategies: an overview'
# 'Ocean fertilization: a potential means of geoengineering?'
# attached to UT object
# 'Ocean iron fertilization and international law'
# attached to UT object
# 'Geoengineering: could we or should we make it work?'
# "Revisiting Carbon Flux Through the Ocean's Twilight Zone"
# 'Is Ocean Fertilization Credible and Creditable?'
# 'Dis-Crediting Ocean Fertilization'
# 'Possible biogeochemical consequences of ocean fertilization'
# 'Factors limiting the reduction of atmospheric CO2 by iron fertilization'
# 'Climate change, ocean processes and ocean iron fertilization'
# attached to UT object
# 'Iron enrichment stimulates toxic diatom production in high-nitrate, low-chlorophyll areas'
# attached to UT object
# 'Effects of patchy ocean fertilization onatmospheric carbon dioxide and biologicalproduction'
# 'A New Database to Explore the Findings from Large-Scale Ocean Iron Enrichment Experiments'
# 'IronEx-I, an in situ iron-enrichment experiment: Experimental design, implementation and results'
# attached to UT object
# 'Surface seawater distributions of inorganic carbon and nutrients around the Galapagos Islands: results from the PlumEx experiment using automated chemical mapping'
# 'The high-nutrient, low-chlorophyll regime of the ocean: limits on biomass and nitrate before and after iron enrichment'
# 'Status of the iron hypothesis after the Open-Ocean Enrichment Experiment'
# 'Mesoscale Iron Enrichment Experiments 1993-2005: Synthesis and Future Directions'
# 'Implications of large-scale iron fertilization of the oceans'
# 'Will Ocean Fertilization Work?'
# 'Ocean Fertilization: Science, Policy, and Commerce'
# 'Synthesis of iron fertilization experiments: From the Iron Age in the Age of Enlightenment'
# 'Organizations Urge Caution on Ocean Fertilization Experiments'
# 'Iron and mixing affect biological carbon uptake in SOIREE and EisenEx, two Southern Ocean iron fertilisation experiments'
# attached to UT object
# 'Taking a Precautionary Approach to Climate Mitigation Measures in the Southern Ocean'
# 'The southern ocean at the Last Glacial Maximum: A strong sink for atmospheric carbon dioxide'
# 'Climatic effect of Southern Ocean Fe fertilization: Is the jury still out?'
# FOUND 0 docs in database

# %%
t.name
# Out:
# 'NETs - General'

# %%
p = Project.objects.get(pk=2)
for t in Technology.objects.filter(project=2):
    new_docs = alldocs.filter(
        wos=False,
        scopus=False,
        query__upload_link__category=t
    ) | alldocs.filter(
        wos=False,
        scopus=False,
        technology=t
    )
    new_docs = new_docs.distinct()
    q = Query(
        project=p,
        title="New documents uploaded by users, with user tech tags: {}".format(t.name),
        text="[Auto generated]",
        r_count=new_docs.count(),
        creator=User.objects.get(username="galm"),
        technology=t
    )
    print(new_docs.count())
    q.save()
    tag = Tag(
        title="all",
        query=q
    )
    tag.save()
    for d in new_docs:
        d.query.add(q)
        d.tag.add(tag)
        d.save()
    print(t)
# Out:
# 48
# NETs - General
# 39
# BECCS
# 10
# Ocean Alkalinisation
# 31
# Bioenergy
# 48
# Afforestation/reforestation
# 3
# Ethics & Morals
# 27
# Biochar
# 50
# Direct Air Capture
# 73
# Ocean fertilisation
# 76
# Soil Carbon Sequestration
# 8
# Geological Storage
# 8
# Enhanced Weathering
# 4
# Blue Carbon

# %%
ems = EmailTokens.objects.filter(sent=True,category__gt=1,category__project=2)


for em in ems.iterator():
    em.valid_docs = Doc.objects.filter(query__upload_link=em,wosarticle__ti__isnull=False).distinct().count()
    em.save()
    
    


df = pd.DataFrame.from_dict(list(ems.values()))



df.head()
# Out:
#                AU  category_id  clicked  \
# 0       Abegaz, A            9        2
# 1  Longbottom, ML            9        0
# 2    Canadell, JG            2        2
# 3       Sholl, DS            5        1
# 4   Nikulshina, V            5        1
#
#                                               docset  \
# 0  Abegaz, A, Winowiecki, LA, Vagen, TG, Langan, ...
# 1  Longbottom, ML, Petrie, PR (2015) Role of vine...
# 2  Canadell, JG, Raupach, MR (2008) Managing fore...
# 3  Choi, S, Watanabe, T, Bae, TH, Sholl, DS, Jone...
# 4  Nikulshina, V, Hirsch, D, Mazzotti, M, Steinfe...
#
#                           email                                    id  \
# 0      assefa.abegaz@aau.edu.et  9b7c8720-9fdb-4685-9d76-580d94cf2d7c
# 1  mardi.longbottom@awri.com.au  b6ffa8b0-5432-4a38-887f-c33eeb62cc22
# 2         pep.canadell@csiro.au  d9c927a8-7f17-4adb-876c-20ef94d85e74
# 3   david.sholl@chbe.gatech.edu  e34dcf93-7249-4118-8472-7c24f79bbf01
# 4         aldo.steinfeld@eth.ch  8569b124-3713-4367-81ec-a543b515a397
#
#    project_id  sent sent_other_project sent_other_tech user_id  valid_docs
# 0         NaN  True              False           False    None           0
# 1         NaN  True              False           False    None           0
# 2         NaN  True              False           False    None           0
# 3         NaN  True              False           False    None           0
# 4         NaN  True              False           False    None           1

# %%
em_bycat = ems.values('category__name').annotate(
    a_emails_sent = Count('id'),
    b_clicks_received = Sum('clicked'),
    #c_docs_added = Sum('valid_docs'),
    #c = Subquery(query__doc.filter(wosarticle__ti__isnull=False))
    c_docs_added = models.Sum(
        models.Case(
            models.When(query__doc__wosarticle__ti__isnull=False, then=1),
            default=0, output_field=models.IntegerField()
        )
    )
)

bc = pd.DataFrame.from_dict(list(em_bycat))

bc.head(15)
# Out:
#     a_emails_sent  b_clicks_received  c_docs_added  \
# 0             102                253            33
# 1               3                  0             0
# 2              31                 51             6
# 3              76                 56            13
# 4             167               1722            56
# 5             166                734            43
# 6              31                 47            10
# 7             335                616            81
# 8               5                  7             1
# 9             308                459            52
# 10             32                 66             9
#
#                  category__name
# 0                NETs - General
# 1               Ethics & Morals
# 2            Geological Storage
# 3                       Biochar
# 4            Direct Air Capture
# 5           Ocean fertilisation
# 6           Enhanced Weathering
# 7     Soil Carbon Sequestration
# 8          Ocean Alkalinisation
# 9   Afforestation/reforestation
# 10                    Bioenergy

# %%
plt.rcParams["figure.figsize"] = [8,5]


pdf = bc.set_index('category__name')

pdf.plot.bar()

plt.text(0.5,800,"Emails sent: {}".format(pdf['a_emails_sent'].sum()))
plt.text(0.5,700,"Clicks recieved: {}".format(pdf['b_clicks_received'].sum()))
plt.text(0.5,600,"Docs added: {}".format(pdf['c_docs_added'].sum()))

plt.xlabel('Technology Category')

ls = ["Emails sent", "Clicks received", "Docs added"]

for i,t in enumerate(plt.legend().get_texts()):
    t.set_text(ls[i])
    
plt.xticks(rotation=45,ha="right")
plt.savefig('../plots/general/emails_responses.pdf',bbox_inches='tight') 
plt.savefig('../plots/general/emails_responses.png',bbox_inches='tight') 
plt.show()

# %%
newqs = Query.objects.filter(id__gt=2286,id__lt=2300,project=2,creator__username="galm")

newdocs = Doc.objects.filter(query__in=newqs)

print(newdocs.distinct().count())
# Out:
# 273

# %%
doc_ids = []
rated_docs = []
unrated_docs = []
all_docs = []
p_docs = []
n_docs = []
for q in newqs:
    print(q.title)
    qdocs = Doc.objects.filter(query=q)
    all_docs.append(list(qdocs.values_list('id',flat=True)))
    print(qdocs.count())
    # Any ratings
    ratings = DocOwnership.objects.filter(query=q,relevant__gt=0)
    print(ratings.count())
    rdocs = qdocs.filter(id__in=list(set(ratings.values_list('doc__id',flat=True))))
    rated_docs.append(list(set(list(rdocs.values_list('id',flat=True)))))
    
    # Negative ratings
    nrs = DocOwnership.objects.filter(query=q,relevant=2)
    n_docs.append(list(set(list(qdocs.filter(
        id__in=list(set(nrs.values_list('doc__id',flat=True)))
    ).values_list('id',flat=True)))))
    
    # Positive ratings
    prs = DocOwnership.objects.filter(query=q,relevant=1)
    pdocs = qdocs.filter(id__in=list(set(prs.values_list('doc__id',flat=True))))
    p_docs.append(list(set(list(pdocs.values_list('id',flat=True)))))
    
    # Unrated docs
    ur_docs = qdocs.exclude(id__in=list(set(ratings.values_list('doc__id',flat=True))))
    unrated_docs.append(list(set(list(ur_docs.values_list('id',flat=True)))))
    
    # All docs in the query that do not have a negative rating
    nrdocs = qdocs.exclude(id__in=list(set(nrs.values_list('doc__id',flat=True))))
    nids = set(list(nrdocs.values_list('id',flat=True)))
    print(len(nids))
    doc_ids.append(list(nids))

print("Total Docs: {}".format(len(list(set(flatten(all_docs))))))
print("Unrated_docs: {}".format(len(list(set(flatten(unrated_docs))))))
print("Potentially relevant (unrated or relevant) Docs: {}".format(len(list(set(flatten(doc_ids))))))
print("Documents rated: {}".format(len(list(set(flatten(rated_docs))))))
print("Documents rated relevant: {}".format(len(list(set(flatten(p_docs))))))
print("Documents rated irrelevant: {}".format(len(list(set(flatten(n_docs))))))
# Out:
# New documents uploaded by users, with user tech tags: NETs - General
# 48
# 48
# 25
# New documents uploaded by users, with user tech tags: BECCS
# 39
# 39
# 28
# New documents uploaded by users, with user tech tags: Ocean Alkalinisation
# 10
# 10
# 2
# New documents uploaded by users, with user tech tags: Bioenergy
# 31
# 31
# 27
# New documents uploaded by users, with user tech tags: Afforestation/reforestation
# 48
# 48
# 11
# New documents uploaded by users, with user tech tags: Ethics & Morals
# 3
# 3
# 1
# New documents uploaded by users, with user tech tags: Biochar
# 27
# 27
# 22
# New documents uploaded by users, with user tech tags: Direct Air Capture
# 50
# 50
# 28
# New documents uploaded by users, with user tech tags: Ocean fertilisation
# 62
# 73
# 26
# New documents uploaded by users, with user tech tags: Soil Carbon Sequestration
# 76
# 76
# 14
# New documents uploaded by users, with user tech tags: Geological Storage
# 8
# 8
# 8
# New documents uploaded by users, with user tech tags: Enhanced Weathering
# 8
# 8
# 2
# New documents uploaded by users, with user tech tags: Blue Carbon
# 4
# 0
# 4
# Total Docs: 273
# Unrated_docs: 4
# Potentially relevant (unrated or relevant) Docs: 155
# Documents rated: 273
# Documents rated relevant: 150
# Documents rated irrelevant: 169

# %%
relevant = Doc.objects.filter(id__in=set(flatten(p_docs)))
relevant.count()
p = Project.objects.get(pk=2)
oqs = Query.objects.filter(pk=2359)
oqdocs = Doc.objects.filter(query__in=oqs)
q, created = Query.objects.get_or_create(
    project=p,
    title="Relevant new docs_3",
    text="[Auto generated]",
    creator=User.objects.get(username="galm") 
)
q.save()
for r in relevant:
    if r.id not in list(oqs.values_list('id',flat=True)):
        r.query.add(q)
        
q.r_count = q.doc_set.count()
q.save()

# %%
r.id
# Out:
# 761405

# %%
doc_ids = []
rated_docs = []
for q in newqs:
    print(q.technology.name)
    qdocs = Doc.objects.filter(query=q)
    print("{} documents".format(qdocs.count()))
    # Any ratings
    ratings = DocOwnership.objects.filter(query=q,relevant__gt=0)
    #print(ratings.count())
    rdocs = qdocs.filter(id__in=list(set(ratings.values_list('doc__id',flat=True))))
    rdoc_ids = set(ratings.values_list('doc__id',flat=True))
    
    print("{} rated".format(len(rdoc_ids)))
    
    dos = DocOwnership.objects.filter(query=q)
    users = User.objects.filter(docownership__in=dos).distinct()
    users = ', '.join([u.username + " " + u.email for u in users])

    print("Users: {}\n".format(users))
# Out:
# NETs - General
# 48 documents
# 48 rated
# Users: minj minx@mcc-berlin.net, galm callaghan@mcc-berlin.net
#
# BECCS
# 39 documents
# 39 rated
# Users: minj minx@mcc-berlin.net, delm mariaz09@gmail.com
#
# Ocean Alkalinisation
# 10 documents
# 10 rated
# Users: atho thorben.amann@uni-hamburg.de, garw wagner.oliveira.garcia@uni-hamburg.de
#
# Bioenergy
# 31 documents
# 31 rated
# Users: minj minx@mcc-berlin.net, delm mariaz09@gmail.com
#
# Afforestation/reforestation
# 48 documents
# 48 rated
# Users: lamw lamw@mcc-berlin.net, fuss fuss@mcc-berlin.net
#
# Ethics & Morals
# 3 documents
# 0 rated
# Users: lend
#
# Biochar
# 27 documents
# 27 rated
# Users: vicl VicenteVicente@mcc-berlin.net
#
# Direct Air Capture
# 50 documents
# 0 rated
# Users: cref creutzig@mcc-berlin.net
#
# Ocean fertilisation
# 62 documents
# 73 rated
# Users: atho thorben.amann@uni-hamburg.de, garw wagner.oliveira.garcia@uni-hamburg.de
#
# Soil Carbon Sequestration
# 76 documents
# 76 rated
# Users: khat tarun.kh@gmail.com, smip pete.smith@abdn.ac.uk
#
# Geological Storage
# 8 documents
# 8 rated
# Users: minj minx@mcc-berlin.net, delm mariaz09@gmail.com
#
# Enhanced Weathering
# 8 documents
# 8 rated
# Users: atho thorben.amann@uni-hamburg.de, garw wagner.oliveira.garcia@uni-hamburg.de
#
# Blue Carbon
# 4 documents
# 0 rated
# Users: minj minx@mcc-berlin.net

# %%
dos = DocOwnership.objects.filter(query__in=newqs,relevant=2)
print(dos.count())
dos.values()
# Out:
# 137
# <QuerySet [{'date': datetime.datetime(2018, 2, 8, 13, 25, 1, 757458, tzinfo=<UTC>), 'query_id': 2287, 'id': 42117, 'user_id': 1, 'tag_id': 529, 'relevant': 2, 'doc_id': 757687}, {'date': datetime.datetime(2018, 2, 8, 13, 24, 9, 558550, tzinfo=<UTC>), 'query_id': 2287, 'id': 42113, 'user_id': 1, 'tag_id': 529, 'relevant': 2, 'doc_id': 761334}, {'date': datetime.datetime(2018, 2, 8, 13, 22, 54, 31791, tzinfo=<UTC>), 'query_id': 2287, 'id': 42109, 'user_id': 1, 'tag_id': 529, 'relevant': 2, 'doc_id': 757705}, {'date': datetime.datetime(2018, 2, 8, 13, 19, 44, 876179, tzinfo=<UTC>), 'query_id': 2287, 'id': 42103, 'user_id': 1, 'tag_id': 529, 'relevant': 2, 'doc_id': 757789}, {'date': datetime.datetime(2018, 2, 8, 13, 19, 32, 645295, tzinfo=<UTC>), 'query_id': 2287, 'id': 42101, 'user_id': 1, 'tag_id': 529, 'relevant': 2, 'doc_id': 761335}, {'date': datetime.datetime(2018, 2, 8, 13, 19, 6, 970869, tzinfo=<UTC>), 'query_id': 2287, 'id': 42099, 'user_id': 1, 'tag_id': 529, 'relevant': 2, 'doc_id': 757788}, {'date': datetime.datetime(2018, 2, 8, 13, 15, 23, 139897, tzinfo=<UTC>), 'query_id': 2287, 'id': 42089, 'user_id': 1, 'tag_id': 529, 'relevant': 2, 'doc_id': 757644}, {'date': datetime.datetime(2018, 2, 8, 13, 15, 10, 222005, tzinfo=<UTC>), 'query_id': 2287, 'id': 42087, 'user_id': 1, 'tag_id': 529, 'relevant': 2, 'doc_id': 761289}, {'date': datetime.datetime(2018, 2, 8, 13, 14, 54, 484959, tzinfo=<UTC>), 'query_id': 2287, 'id': 42085, 'user_id': 1, 'tag_id': 529, 'relevant': 2, 'doc_id': 747035}, {'date': datetime.datetime(2018, 2, 8, 13, 12, 27, 250303, tzinfo=<UTC>), 'query_id': 2287, 'id': 42083, 'user_id': 1, 'tag_id': 529, 'relevant': 2, 'doc_id': 747728}, {'date': datetime.datetime(2018, 2, 8, 13, 10, 29, 626978, tzinfo=<UTC>), 'query_id': 2287, 'id': 42079, 'user_id': 1, 'tag_id': 529, 'relevant': 2, 'doc_id': 761333}, {'date': datetime.datetime(2018, 2, 8, 13, 9, 4, 433876, tzinfo=<UTC>), 'query_id': 2287, 'id': 42077, 'user_id': 1, 'tag_id': 529, 'relevant': 2, 'doc_id': 757686}, {'date': datetime.datetime(2018, 2, 8, 13, 8, 51, 635558, tzinfo=<UTC>), 'query_id': 2287, 'id': 42075, 'user_id': 1, 'tag_id': 529, 'relevant': 2, 'doc_id': 758029}, {'date': datetime.datetime(2018, 2, 8, 13, 7, 57, 172225, tzinfo=<UTC>), 'query_id': 2287, 'id': 42073, 'user_id': 1, 'tag_id': 529, 'relevant': 2, 'doc_id': 757763}, {'date': datetime.datetime(2018, 2, 8, 13, 7, 28, 262865, tzinfo=<UTC>), 'query_id': 2287, 'id': 42071, 'user_id': 1, 'tag_id': 529, 'relevant': 2, 'doc_id': 757647}, {'date': datetime.datetime(2018, 2, 8, 13, 2, 34, 294563, tzinfo=<UTC>), 'query_id': 2287, 'id': 42063, 'user_id': 1, 'tag_id': 529, 'relevant': 2, 'doc_id': 758062}, {'date': datetime.datetime(2018, 2, 8, 12, 48, 2, 755770, tzinfo=<UTC>), 'query_id': 2287, 'id': 42057, 'user_id': 1, 'tag_id': 529, 'relevant': 2, 'doc_id': 761290}, {'date': datetime.datetime(2018, 2, 8, 12, 42, 31, 714227, tzinfo=<UTC>), 'query_id': 2287, 'id': 42053, 'user_id': 1, 'tag_id': 529, 'relevant': 2, 'doc_id': 757640}, {'date': datetime.datetime(2018, 2, 8, 12, 40, 15, 511415, tzinfo=<UTC>), 'query_id': 2287, 'id': 42049, 'user_id': 1, 'tag_id': 529, 'relevant': 2, 'doc_id': 757708}, {'date': datetime.datetime(2018, 2, 8, 12, 39, 28, 38784, tzinfo=<UTC>), 'query_id': 2287, 'id': 42047, 'user_id': 1, 'tag_id': 529, 'relevant': 2, 'doc_id': 757642}, '...(remaining elements truncated)...']>

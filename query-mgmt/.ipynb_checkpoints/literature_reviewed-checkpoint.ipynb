# %%
import django, os, sys, time, resource, re, gc, shutil
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from django.db.models import Count, Avg, F, Sum
import math

sys.path.append('/home/galm/software/django/tmv/BasicBrowser/')

os.environ.setdefault("DJANGO_SETTINGS_MODULE", "BasicBrowser.settings")
django.setup()

from scoping.models import *
from utils.utils import ars

qid = 1558
q = Query.objects.get(pk=qid)

# %%
p = Project.objects.get(title="NETs")
pdocs = Doc.objects.filter(query__project=p)

techs = Technology.objects.filter(project=p).exclude(name__in=["Bioenergy","Storage","Blue Carbon"])

techs = Technology.objects.filter(project=p).exclude(name__in=["Blue Carbon"])

tdocs = set(list(Doc.objects.filter(
    technology__in=techs
).values_list('UT',flat=True)))

qtdocs = set(list(Doc.objects.filter(
    query__technology__in=techs
).values_list('UT',flat=True)))

## These are all docs in the project

pdocs =  Doc.objects.filter(
    UT__in=tdocs.union(qtdocs)
)

print(pdocs.distinct().count())#techs = Technology.objects.filter(project=p)
# Out:
# 7604

# %%
queries = Query.objects.filter(technology__in=techs,doc__isnull=False,type="default").distinct()

qts = queries.annotate(
    ndocs = Count('doc')
)

qtdf = pd.DataFrame.from_dict(list(qts.sort_by('id').values('id','technology__name','ndocs','title','text','database')))

qtdf.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-78-214f8348afba> in <module>()
#       5 )
#       6
# ----> 7 qtdf = pd.DataFrame.from_dict(list(qts.sort('id').values('id','technology__name','ndocs','title','text','database')))
#       8
#       9 qtdf.head()
#
# AttributeError: 'QuerySet' object has no attribute 'sort'

# %%
trdocs = set(list(pdocs.filter(
    docownership__relevant=1,
    docownership__query__technology__in=techs
).values_list('UT',flat=True)))

ttdocs = set(list(Doc.objects.filter(
    technology__in=techs
).values_list('UT',flat=True)))


allreldocs =  Doc.objects.filter(
    UT__in=trdocs.union(ttdocs)
)

print(allreldocs.count())
# Out:
# 1997

# %%
global unfound
unfound = 0

global multmatches
multmatches = 0

global found
found = 0

global indb
indb = 0

spapers = pd.read_csv('../tables/unique_spreadsheet_papers.csv')


def find_paper(x):
    
    try:
    
        tis = x['X3'].split()
        
    except:
        print(x['X3'])
        tis = str(x['X3']).split()
    
    if len(tis) > 8:
        ti = ' '.join(tis[:8])
    else:
        ti = x['X3']
        
    docs = pdocs.filter(title__icontains=ti)
    
    global unfound
    global found
    global multmatches
    
    if docs.count() == 1:
    
        doc = docs.first()
        found +=1
    elif docs.count() > 1:
        doc = "None"
        multmatches+=1
    else:       
        di = x['X3'].replace('http://dx.doi.org/','')
        docs = pdocs.filter(wosarticle__di=di)
        if docs.count()==1:
            doc = docs.first()
            found+=1
        elif docs.count() > 1:
            doc = "None"
            multmatches+=1
        else:
            au = x['X1'].split()[0].split(',')[0]
            docs = pdocs.filter(docauthinst__AU__icontains=au,docauthinst__position=1,PY=x['X2']).distinct()
            if docs.count()==1:
                doc = docs.first()
                found+=1
            elif docs.count() > 1:
                doc = "None"
                multmatches+=1
            else:
                docs = pdocs.filter(docauthinst__AU__icontains=au,docauthinst__position__in=[1,0],PY=x['X2']).distinct()
                if docs.count()==1:
                    doc = docs.first()
                    found+=1
                else:
                    ti = re.findall('[A-Z]{1}\.{1}[^;]([^\.]{5,})',x['X3'])
                    if len(ti) > 0:
                        ti = ti[0]
                    else:
                        ti = "zwasdfölkjag"
                    docs = pdocs.filter(title__icontains=ti)
                    if docs.count()==1:
                        doc = docs.first()
                        found+=1
                    else:
                        doc = "None"
                        unfound+=1
                        
    try:
        doc = doc.UT
    except:
        doc = doc
    
    return doc

spapers['doc_id'] = spapers.apply(lambda x: find_paper(x), axis=1)

print("no matches: {}".format(unfound))
print("multiple matches: {}".format(multmatches))
print("found {}".format(found))


spapers.head()
# Out:
# nan
# no matches: 43
# multiple matches: 15
# found 803
#    Unnamed: 0                     X1      X2  \
# 0           1            Renforth, P  2012.0
# 1           3  Schuiling & Krijgsman  2006.0
# 2           4          Köhler et al.  2010.0
# 3           5          Taylor et al.  2016.0
# 4           6         Hangx & Spiers  2009.0
#
#                                                   X3  \
# 0     The potential of enhanced weathering in the UK
# 1  ENHANCED WEATHERING: AN EFFECTIVE AND CHEAP TO...
# 2  Geoengineering potential of artificially enhan...
# 3  Enhanced weathering strategies for stabilizing...
# 4  Coastal spreading of olivine to control atmosp...
#
#                                     technology               doc_id
# 0  Enhanced weathering (terrestrial and ocean)  WOS:000309790500021
# 1  Enhanced weathering (terrestrial and ocean)  WOS:000237646500016
# 2  Enhanced weathering (terrestrial and ocean)  WOS:000284529000019
# 3  Enhanced weathering (terrestrial and ocean)  WOS:000373060000019
# 4  Enhanced weathering (terrestrial and ocean)  WOS:000272373000010

# %%
spapers[spapers['doc_id'] == "None"].reset_index()['X3']


notfound = spapers[spapers['doc_id'] == "None"].reset_index()

foundpapers = spapers[spapers['doc_id'] != "None"].reset_index()

notfound



#notfound.to_excel('../tables/spreadsheet_not_found.xlsx')


#spapers[spapers['doc_id'] == "None"].groupby('technology').count()

# Go through docs, mark include1 if in allreldocs, mark include2 if in list generated in R


#spapers[spapers['doc_id'] == "None"].reset_index()['X3'][18]
# Out:
#     index  Unnamed: 0                                                 X1  \
# 0      34          36  Xiaoming Feng, Bojie Fu, Shilong Piao, Shuai W...
# 1      69          71                                           Xiao, JF
# 2     108         110                           Arora, VK, Montenegro, A
# 3     128         130                                         Lenton, TM
# 4     132         136                 Xu, B, Guo, ZD, Piao, SL, Fang, JY
# 5     134         138                                        Gorte, R.W.
# 6     150         154  Henry, M, Tittonell, P, Manlay, RJ, Bernoux, M...
# 7     196         202                                         Glenday, J
# 8     213         219                                Melvin G.R. Cannell
# 9     214         222                          Sohngen, B, Mendelsohn, R
# 10    223         232                               Stavins and Richards
# 11    239         248                                             Kaiser
# 12    249         258                                              Brown
# 13    272         282                                                NaN
# 14    273         343                                              Zeman
# 15    278         348                                       APS/ Socolow
# 16    302         373                               Renforth & Henderson
# 17    304         375                                  Sarmiento and Orr
# 18    308         379                                        Joos et al.
# 19    406         485  Shi, J., Liu, J., Gao, Z., Cui, L. (2005) A re...
# 20    410         494  Si, J., Jia, L.-M., Wei, Y.-K., Xing, C.-S., L...
# 21    785         934                                             Ahamer
# 22    787         937                                    Nordstrm, E.-M.
# 23    818         997                                       Rogner et al
# 24    820        1001                                             Thraen
# 25    821        1005                                            Battjes
# 26    822        1006                                        Bauen et al
# 27    823        1007                                  Cornelissen et al
# 28    826        1020                                              Smith
# 29    830        1033  Dooley, J.J.; Dahowski, R.T.; Davidson, C.L.; ...
# 30    831        1034                                            Ormerod
# 31    832        1035                           Vangkilde-Peterson et al
# 32    834        1053  Shogenova, A.; Shogenov, K.; Vahera, R.; Ivask...
# 33    835        1054  Anthonsen, K.L.; Aagaard, P.; Bergmo, P.E.S.; ...
# 34    836        1055  Wildenborg, T.; Gale, J.; Hendriks, C.; Hollow...
# 35    837        1056                           Vangkilde-Peterson et al
# 36    838        1058  Wright, R.; Mourits, F.; RodrÃ­guez, L.B.; Ser...
# 37    839        1060                              HENDRIKS, CA; BLOK, K
# 38    840        1064  Li, X.; Wei, N.; Liu, Y.; Fang, Z.; Dahowski, ...
# 39    842        1066  Movagharnejad, K; Emamgholivand, A; Mousavi, H...
# 40    843        1086                   Godec, M.; Koperna, G.; Gale, J.
# 41    844        1088                                    IEAGHG - PH3-22
# 42    845        1102                                             IEAGHG
# 43    846        1110                                    Gale and Freund
# 44    847        1117  Vello A. Kuuskraa, Charles M. Boyer II, Jonath...
# 45    848        1120                                       Dooley, J.J.
# 46    849        1127                      Gunter, Wong, Cheel, Sjostrom
# 47    850        1135  Holloway, S.; Garg, A.; Kapshe, M.; Deshpande,...
# 48    851        1136                                        Koide et al
# 49    852        1139  Grimston, MC; Karakoussis, V; Fouquet, R; van ...
# 50    853        1166                                               IPCC
# 51    854        1178                               Bentham, M; Kirby, G
# 52    855        1181  Shogenova, A.; Sliaupa, S.; Shogenov, K.; Vahe...
# 53    856        1193  Shogenova, A; Sliaupa, S; Sliaupa, S; Vaher, R...
# 54    857        1201                                               Gale
# 55    858        1203  Dahowski, R.T.; Dooley, J.J.; Davidson, C.L.; ...
# 56    859        1204                            Holler, S.; Viebahn, P.
# 57    860        1205                            Aktouf, A; Bentellis, A
#
#         X2                                                 X3  \
# 0   2016.0  Revegetation in China's Loess Plateau is appro...
# 1   2014.0  Satellite evidence for significant biophysical...
# 2   2011.0  Small temperature benefits provided by realist...
# 3   2010.0  The potential for land-based biological CO2 re...
# 4   2010.0  Biomass carbon stocks in China’s forests betwe...
# 5   2010.0                    Carbon sequestration in forests
# 6   2009.0  Biodiversity, carbon stocks and sequestration ...
# 7   2006.0  Carbon storage and emissions offset potential ...
# 8   2003.0  Carbon sequestration and biomass energy offset...
# 9   2003.0  An Optimal Control Model of Forest Carbon Sequ...
# 10  2002.0  The cost of U.S. forest-based carbon sequestra...
# 11  2000.0            Panel Estimates Possible Carbon 'Sinks'
# 12  1996.0  Management of forests for mitigation of greenh...
# 13     NaN                                                NaN
# 14  2003.0  Zeman, F. S. An Investigation into the Feasibi...
# 15  2011.0  American Physical Society. Direct Air Capture ...
# 16  2017.0  Assessing ocean alkalinity for carbon sequestr...
# 17  1991.0  Three-dimensional simulations of the impact of...
# 18  1991.0  Possible effects of iron fertilization in the ...
# 19  2005.0                             http://dx.doi.org/None
# 20  2012.0  https://www.cabdirect.org/cabdirect/abstract/2...
# 21  1996.0  Biomass energy production: the Global Potentia...
# 22  2015.0  Bioenergy futures: A global outlook on the imp...
# 23  2012.0  Chapter 7 - energy resources and potentials. I...
# 24  2010.0  Global biomass potentials – resources, drivers...
# 25  1994.0  Global options for biofuels from plantations a...
# 26  2004.0  Bioelectricity vision: achieving 15% of electr...
# 27  2012.0  the role of bioenergy in a fully sustainable g...
# 28  2012.0  Global bioenergy capacity as constrained by ob...
# 29  2005.0  A CO2-storage supply curve for North America a...
# 30  1993.0    An Overview of large scale CO2 disposal options
# 31  2009.0  Assessing European capacity for geological sto...
# 32  2011.0  CO2 geological storage capacity analysis in Es...
# 33  2013.0         CO2 storage potential in the Nordic region
# 34  2005.0       Cost curves for CO2 storage: European sector
# 35  2009.0  GeoCapacity Final Report Assessing European Ca...
# 36  2013.0      The first North American carbon storage atlas
# 37  1995.0              UNDERGROUND-STORAGE OF CARBON-DIOXIDE
# 38  2009.0  CO2 point emission and geological storage capa...
# 39  2012.0  Preliminary country-scale assessment of carbon...
# 40  2014.0  CO2-ECBM: A review of its status and global po...
# 41  2000.0  Barriers to overcome the implementation of CO2...
# 42  2009.0                 CO2 storage in depleted Gas fields
# 43  2001.0  Coal-bed methane enhancement with CO2 sequestr...
# 44  1992.0  COALBED GAS-1 HUNT FOR QUALITY BASINS GOES ABROAD
# 45  2013.0  Estimating the supply and demand for deep geol...
# 46  1998.0  Large CO2 Sinks: Their role in the mitigation ...
# 47  2009.0  An assessment of the CO2 storage potential of ...
# 48  1992.0  Subterranean containment and long-term storage...
# 49  2001.0  The European and global potential of carbon di...
# 50  2005.0            Underground Geological Storage in SRCCS
# 51  2005.0                     CO2 storage in saline aquifers
# 52  2007.0  Geological storage of CO2 - Prospects in the B...
# 53  2009.0  The Baltic Basin: structure, properties of res...
# 54  2004.0  Using coal seams for CO2 sequestration. Geolog...
# 55  2005.0  Regional differences in carbon dioxide capture...
# 56  2011.0  Assessment of CO2 storage capacity in geologic...
# 57  2016.0  CO2-storage assessment and effective capacity ...
#
#                          technology doc_id
# 0   Afforestation and Reforestation   None
# 1   Afforestation and Reforestation   None
# 2   Afforestation and Reforestation   None
# 3   Afforestation and Reforestation   None
# 4   Afforestation and Reforestation   None
# 5   Afforestation and Reforestation   None
# 6   Afforestation and Reforestation   None
# 7   Afforestation and Reforestation   None
# 8   Afforestation and Reforestation   None
# 9   Afforestation and Reforestation   None
# 10  Afforestation and Reforestation   None
# 11  Afforestation and Reforestation   None
# 12  Afforestation and Reforestation   None
# 13                            BECCS   None
# 14                              DAC   None
# 15                              DAC   None
# 16             Ocean alkalinisation   None
# 17              Ocean fertilization   None
# 18              Ocean fertilization   None
# 19        Soil Carbon Sequestration   None
# 20        Soil Carbon Sequestration   None
# 21                        Bioenergy   None
# 22                        Bioenergy   None
# 23                        Bioenergy   None
# 24                        Bioenergy   None
# 25                        Bioenergy   None
# 26                        Bioenergy   None
# 27                        Bioenergy   None
# 28                        Bioenergy   None
# 29                          Storage   None
# 30                          Storage   None
# 31                          Storage   None
# 32                          Storage   None
# 33                          Storage   None
# 34                          Storage   None
# 35                          Storage   None
# 36                          Storage   None
# 37                          Storage   None
# 38                          Storage   None
# 39                          Storage   None
# 40                          Storage   None
# 41                          Storage   None
# 42                          Storage   None
# 43                          Storage   None
# 44                          Storage   None
# 45                          Storage   None
# 46                          Storage   None
# 47                          Storage   None
# 48                          Storage   None
# 49                          Storage   None
# 50                          Storage   None
# 51                          Storage   None
# 52                          Storage   None
# 53                          Storage   None
# 54                          Storage   None
# 55                          Storage   None
# 56                          Storage   None
# 57                          Storage   None

# %%
print('WOS:000309790500021' in foundpapers['doc_id'].tolist())

foundpapers['doc_id'].tolist()
# Out:
# False
# [<Doc: WOS:000309790500021>,
#  <Doc: WOS:000237646500016>,
#  <Doc: WOS:000284529000019>,
#  <Doc: WOS:000373060000019>,
#  <Doc: WOS:000272373000010>,
#  <Doc: WOS:000307378500011>,
#  <Doc: WOS:000398646500042>,
#  <Doc: WOS:000260293100007>,
#  <Doc: WOS:000371488300009>,
#  <Doc: WOS:000316998300017>,
#  <Doc: WOS:000313220300016>,
#  <Doc: WOS:000288146200002>,
#  <Doc: WOS:000287106700015>,
#  <Doc: WOS:000264867000005>,
#  <Doc: WOS:000251582800043>,
#  <Doc: WOS:000168824703328>,
#  <Doc: WOS:000323230100001>,
#  <Doc: 2-s2.0-84978123737>,
#  <Doc: 2-s2.0-84988701357>,
#  <Doc: WOS:000389184600020>,
#  <Doc: WOS:000392684700013>,
#  <Doc: 2-s2.0-84986325555>,
#  <Doc: 2-s2.0-84992168841>,
#  <Doc: 2-s2.0-84979681368>,
#  <Doc: WOS:000376713100009>,
#  <Doc: WOS:000378949300001>,
#  <Doc: WOS:000380910100076>,
#  <Doc: WOS:000381381100071>,
#  <Doc: WOS:000381828300018>,
#  <Doc: WOS:000381837900016>,
#  <Doc: WOS:000384103400003>,
#  <Doc: WOS:000385598800030>,
#  <Doc: WOS:000388307100015>,
#  <Doc: WOS:000389089300002>,
#  <Doc: WOS:000389961800016>,
#  <Doc: WOS:000391425900009>,
#  <Doc: WOS:000369555700013>,
#  <Doc: WOS:000370887100016>,
#  <Doc: WOS:000371678700007>,
#  <Doc: WOS:000370896400006>,
#  <Doc: WOS:000367755700044>,
#  <Doc: WOS:000358268700005>,
#  <Doc: WOS:000348711100003>,
#  <Doc: WOS:000355035600010>,
#  <Doc: WOS:000348982200014>,
#  <Doc: 2-s2.0-84925264905>,
#  <Doc: WOS:000349005200005>,
#  <Doc: WOS:000355569100002>,
#  <Doc: WOS:000358392400004>,
#  <Doc: WOS:000364461900002>,
#  <Doc: WOS:000355779100045>,
#  <Doc: WOS:000350084600002>,
#  <Doc: WOS:000348747300023>,
#  <Doc: WOS:000352650400009>,
#  <Doc: WOS:000351803300011>,
#  <Doc: WOS:000353073400006>,
#  <Doc: WOS:000350662100041>,
#  <Doc: WOS:000358127300002>,
#  <Doc: WOS:000362612700010>,
#  <Doc: WOS:000366402900002>,
#  <Doc: WOS:000332180900019>,
#  <Doc: WOS:000333506100029>,
#  <Doc: 2-s2.0-84896465314>,
#  <Doc: WOS:000337680700028>,
#  <Doc: WOS:000345061100015>,
#  <Doc: WOS:000341825200031>,
#  <Doc: WOS:000337019300015>,
#  <Doc: WOS:000333723800001>,
#  <Doc: WOS:000344813300012>,
#  <Doc: 2-s2.0-84893982738>,
#  <Doc: WOS:000333854600002>,
#  <Doc: WOS:000327814700066>,
#  <Doc: WOS:000318057900005>,
#  <Doc: WOS:000320503000039>,
#  <Doc: WOS:000314919100004>,
#  <Doc: WOS:000317926500007>,
#  <Doc: WOS:000320687100004>,
#  <Doc: WOS:000324657200011>,
#  <Doc: WOS:000315996800001>,
#  <Doc: WOS:000328522200018>,
#  <Doc: WOS:000326944000006>,
#  <Doc: WOS:000329397600011>,
#  <Doc: WOS:000320425100010>,
#  <Doc: WOS:000322758000027>,
#  <Doc: WOS:000312974200004>,
#  <Doc: WOS:000311193400053>,
#  <Doc: WOS:000327216000010>,
#  <Doc: WOS:000309438200005>,
#  <Doc: WOS:000299468900004>,
#  <Doc: WOS:000312523800003>,
#  <Doc: 2-s2.0-84857016720>,
#  <Doc: WOS:000302986600009>,
#  <Doc: 2-s2.0-84873188451>,
#  <Doc: WOS:000309475800024>,
#  <Doc: WOS:000306633800009>,
#  <Doc: WOS:000305443100007>,
#  <Doc: WOS:000302986600008>,
#  <Doc: WOS:000305478400007>,
#  <Doc: 2-s2.0-84876108024>,
#  <Doc: WOS:000306043800007>,
#  <Doc: WOS:000301095600007>,
#  <Doc: WOS:000300671600009>,
#  <Doc: WOS:000300469700010>,
#  <Doc: WOS:000308329200005>,
#  <Doc: WOS:000309572200020>,
#  <Doc: WOS:000289377800019>,
#  <Doc: WOS:000294155900003>,
#  <Doc: WOS:000288911300013>,
#  <Doc: WOS:000294105500022>,
#  <Doc: 2-s2.0-84863333574>,
#  <Doc: WOS:000292907500020>,
#  <Doc: WOS:000294028000009>,
#  <Doc: WOS:000287637100005>,
#  <Doc: WOS:000293399000001>,
#  <Doc: WOS:000298118300004>,
#  <Doc: WOS:000297367200006>,
#  <Doc: WOS:000290192400004>,
#  <Doc: WOS:000294458200008>,
#  <Doc: WOS:000298580900014>,
#  <Doc: WOS:000302825000048>,
#  <Doc: WOS:000286837900008>,
#  <Doc: WOS:000286964200005>,
#  <Doc: WOS:000299498500006>,
#  <Doc: WOS:000294201400009>,
#  <Doc: WOS:000290451200002>,
#  <Doc: WOS:000279129500015>,
#  <Doc: 2-s2.0-77952967649>,
#  <Doc: WOS:000273996000004>,
#  <Doc: WOS:000274419200035>,
#  <Doc: WOS:000274419400010>,
#  <Doc: 2-s2.0-79952723563>,
#  <Doc: WOS:000274575800014>,
#  <Doc: WOS:000279103700109>,
#  <Doc: WOS:000281275200008>,
#  <Doc: WOS:000278221900015>,
#  <Doc: WOS:000281637800015>,
#  <Doc: WOS:000283086700001>,
#  <Doc: WOS:000279582100005>,
#  <Doc: WOS:000282419700007>,
#  <Doc: WOS:000285108700006>,
#  <Doc: WOS:000283208200007>,
#  <Doc: WOS:000280656900010>,
#  <Doc: WOS:000271874300020>,
#  <Doc: WOS:000264634400017>,
#  <Doc: WOS:000272517100007>,
#  <Doc: WOS:000266196700014>,
#  <Doc: WOS:000207892300001>,
#  <Doc: WOS:000267846300041>,
#  <Doc: WOS:000265174600012>,
#  <Doc: 2-s2.0-84920069557>,
#  <Doc: 2-s2.0-70649109951>,
#  <Doc: WOS:000275958800010>,
#  <Doc: WOS:000264835600002>,
#  <Doc: WOS:000272163100036>,
#  <Doc: WOS:000255694700008>,
#  <Doc: WOS:000256676400029>,
#  <Doc: WOS:000254375100018>,
#  <Doc: WOS:000256676400033>,
#  <Doc: WOS:000256476100006>,
#  <Doc: WOS:000255694700010>,
#  <Doc: 2-s2.0-84882497685>,
#  <Doc: WOS:000261849800004>,
#  <Doc: WOS:000257784700007>,
#  <Doc: WOS:000255694700010>,
#  <Doc: 2-s2.0-56449125974>,
#  <Doc: WOS:000257919600005>,
#  <Doc: WOS:000259865100009>,
#  <Doc: WOS:000265878400006>,
#  <Doc: WOS:000244382000013>,
#  <Doc: WOS:000243741500011>,
#  <Doc: WOS:000243803300009>,
#  <Doc: WOS:000251916500006>,
#  <Doc: 2-s2.0-84865389731>,
#  <Doc: WOS:000242512900003>,
#  <Doc: WOS:000242969200001>,
#  <Doc: WOS:000250260100025>,
#  <Doc: WOS:000249802100004>,
#  <Doc: WOS:000244199800002>,
#  <Doc: WOS:000249063500020>,
#  <Doc: WOS:000242894300011>,
#  <Doc: WOS:000246970400010>,
#  <Doc: WOS:000248911400004>,
#  <Doc: WOS:000248629300002>,
#  <Doc: WOS:000250260100024>,
#  <Doc: WOS:000245445500003>,
#  <Doc: WOS:000241677100011>,
#  <Doc: WOS:000238892100009>,
#  <Doc: WOS:000235780300043>,
#  <Doc: WOS:000240585200001>,
#  <Doc: 2-s2.0-32644433584>,
#  <Doc: WOS:000240663900002>,
#  <Doc: WOS:000240408700005>,
#  <Doc: WOS:000232390200002>,
#  <Doc: WOS:000233075900005>,
#  <Doc: 2-s2.0-33646230290>,
#  <Doc: WOS:000233229000006>,
#  <Doc: WOS:000233075900007>,
#  <Doc: WOS:000229688200008>,
#  <Doc: WOS:000234275400039>,
#  <Doc: WOS:000220005200001>,
#  <Doc: WOS:000221550300007>,
#  <Doc: 2-s2.0-0842330600>,
#  <Doc: WOS:000224603600008>,
#  <Doc: WOS:000221277000005>,
#  <Doc: WOS:000182653700013>,
#  <Doc: 2-s2.0-77956772776>,
#  <Doc: WOS:000181309100007>,
#  <Doc: WOS:000185058300010>,
#  <Doc: WOS:000183709500001>,
#  <Doc: WOS:000186272100008>,
#  <Doc: WOS:000186402700003>,
#  <Doc: WOS:000177340500005>,
#  <Doc: 2-s2.0-0036103181>,
#  <Doc: WOS:000178379200002>,
#  <Doc: WOS:000182500200003>,
#  <Doc: WOS:000173716100006>,
#  <Doc: 2-s2.0-0035700810>,
#  <Doc: WOS:000167812800003>,
#  <Doc: WOS:000172173800004>,
#  <Doc: 2-s2.0-0035698517>,
#  <Doc: 2-s2.0-0035698440>,
#  <Doc: WOS:000208093500003>,
#  <Doc: WOS:000087330000005>,
#  <Doc: 2-s2.0-0002101223>,
#  <Doc: 2-s2.0-84885742283>,
#  <Doc: WOS:000085982600021>,
#  <Doc: 2-s2.0-0034456487>,
#  <Doc: WOS:000088146200038>,
#  <Doc: WOS:000083309500005>,
#  <Doc: 2-s2.0-30244476090>,
#  <Doc: WOS:000084046400004>,
#  <Doc: 2-s2.0-0005110251>,
#  <Doc: WOS:000076181000005>,
#  <Doc: WOS:000071586800007>,
#  <Doc: 2-s2.0-0031412274>,
#  <Doc: WOS:A1997WM11600010>,
#  <Doc: 2-s2.0-0030781584>,
#  <Doc: WOS:A1996TW62200013>,
#  <Doc: WOS:A1996TW62200014>,
#  <Doc: WOS:A1995RH59000003>,
#  <Doc: WOS:A1995RD07900019>,
#  <Doc: WOS:A1995UK05300019>,
#  <Doc: WOS:A1995TN24800003>,
#  <Doc: WOS:A1994NU08100007>,
#  <Doc: WOS:A1994ND59700014>,
#  <Doc: WOS:A1994PV45400004>,
#  <Doc: 2-s2.0-0027675976>,
#  <Doc: 2-s2.0-0027796994>,
#  <Doc: WOS:A1993LG78400006>,
#  <Doc: WOS:A1993LH54500003>,
#  <Doc: WOS:A1993LY92000002>,
#  <Doc: WOS:A1993LZ84600018>,
#  <Doc: WOS:A1992JA71500014>,
#  <Doc: WOS:A1992JW13300006>,
#  <Doc: WOS:A1992JC93500001>,
#  <Doc: WOS:A1992JA71500015>,
#  <Doc: WOS:A1991JD40400002>,
#  <Doc: 2-s2.0-0027047895>,
#  <Doc: WOS:000300205200020>,
#  <Doc: WOS:000237646500003>,
#  <Doc: WOS:000240821500003>,
#  <Doc: WOS:000254890400011>,
#  <Doc: WOS:000269881400008>,
#  <Doc: WOS:000298289400040>,
#  <Doc: 2-s2.0-79955370696>,
#  <Doc: WOS:000305719500030>,
#  <Doc: WOS:000307462300011>,
#  <Doc: WOS:000317926500009>,
#  <Doc: WOS:000343016600088>,
#  <Doc: WOS:000392457700034>,
#  <Doc: WOS:000392910900014>,
#  <Doc: WOS:000374333000013>,
#  <Doc: WOS:000377935100041>,
#  <Doc: WOS:000382584300014>,
#  <Doc: WOS:000385469400008>,
#  <Doc: WOS:000352048100020>,
#  <Doc: WOS:000340330500029>,
#  <Doc: WOS:000312523800006>,
#  <Doc: WOS:000380910100070>,
#  <Doc: WOS:000380817000008>,
#  <Doc: WOS:000326773400046>,
#  <Doc: WOS:000324153700018>,
#  <Doc: WOS:000323301300014>,
#  <Doc: WOS:000261307200055>,
#  <Doc: WOS:000247662200018>,
#  <Doc: WOS:000082753400002>,
#  <Doc: v9qwe>,
#  <Doc: WOS:000238570200002>,
#  <Doc: 2-s2.0-41249086935>,
#  <Doc: WOS:000258810800019>,
#  <Doc: gneqk>,
#  <Doc: WOS:A1993KW45000014>,
#  <Doc: 2-s2.0-0025925743>,
#  <Doc: z7z5m>,
#  <Doc: WOS:000168824703311>,
#  <Doc: WOS:000169483400004>,
#  <Doc: WOS:000207911200003>,
#  <Doc: WOS:000220745100001>,
#  <Doc: WOS:000222798500001>,
#  <Doc: WOS:000229210800004>,
#  <Doc: WOS:000229525800006>,
#  <Doc: WOS:000268876600011>,
#  <Doc: WOS:000269828100021>,
#  <Doc: WOS:000273985700048>,
#  <Doc: WOS:000274788200002>,
#  <Doc: WOS:000299714000008>,
#  <Doc: WOS:000304617700004>,
#  <Doc: WOS:000321742600011>,
#  <Doc: WOS:000332668000004>,
#  <Doc: WOS:000346110900004>,
#  <Doc: WOS:000229531600006>,
#  <Doc: WOS:000349731800012>,
#  <Doc: WOS:000283645400007>,
#  <Doc: WOS:000370491400029>,
#  <Doc: WOS:000273433200046>,
#  <Doc: WOS:000306571800004>,
#  <Doc: 2-s2.0-84949179755>,
#  <Doc: WOS:000283602400006>,
#  <Doc: WOS:000373555500031>,
#  <Doc: WOS:000279182300010>,
#  <Doc: WOS:000312738100004>,
#  <Doc: WOS:000315388200003>,
#  <Doc: WOS:000352039500039>,
#  <Doc: WOS:000315388200010>,
#  <Doc: WOS:000311982600007>,
#  <Doc: WOS:000287892400016>,
#  <Doc: WOS:000380913500001>,
#  <Doc: WOS:000370492100010>,
#  <Doc: 2-s2.0-84947248274>,
#  <Doc: WOS:000335275500018>,
#  <Doc: WOS:000325423500116>,
#  <Doc: WOS:000353100900007>,
#  <Doc: WOS:000388960300006>,
#  <Doc: WOS:000295753000065>,
#  <Doc: WOS:000387807200014>,
#  <Doc: WOS:000356491400010>,
#  <Doc: WOS:000329604900056>,
#  <Doc: WOS:000383291700053>,
#  <Doc: WOS:000330824100003>,
#  <Doc: WOS:000363253900018>,
#  <Doc: WOS:000296756500003>,
#  <Doc: WOS:000356191700020>,
#  <Doc: WOS:000355187300026>,
#  <Doc: WOS:000353100900009>,
#  <Doc: WOS:000346726500001>,
#  <Doc: WOS:000385848900001>,
#  <Doc: WOS:000208650300016>,
#  <Doc: WOS:000374060500001>,
#  <Doc: WOS:000315388200012>,
#  <Doc: WOS:000312523800007>,
#  <Doc: 2-s2.0-84891941813>,
#  <Doc: WOS:000272287900024>,
#  <Doc: WOS:000332839300078>,
#  <Doc: WOS:000305966900002>,
#  <Doc: WOS:000376543600004>,
#  <Doc: WOS:000376015900022>,
#  <Doc: WOS:000315388200013>,
#  <Doc: WOS:000374441700001>,
#  <Doc: WOS:000309450300006>,
#  <Doc: WOS:000311390600028>,
#  <Doc: WOS:000383300200026>,
#  <Doc: WOS:000356491400025>,
#  <Doc: WOS:000338393500005>,
#  <Doc: WOS:000385945600001>,
#  <Doc: WOS:000376803400015>,
#  <Doc: WOS:000368951700001>,
#  <Doc: WOS:000371226700048>,
#  <Doc: WOS:000332517800007>,
#  <Doc: WOS:000314063200004>,
#  <Doc: WOS:000343752300002>,
#  <Doc: 2-s2.0-84929538947>,
#  <Doc: WOS:000342852200001>,
#  <Doc: WOS:000366872300094>,
#  <Doc: WOS:000341825200015>,
#  <Doc: WOS:000292862000010>,
#  <Doc: WOS:000282558700001>,
#  <Doc: WOS:000389088400033>,
#  <Doc: WOS:000300974500004>,
#  <Doc: WOS:000374492100001>,
#  <Doc: WOS:000339692700043>,
#  <Doc: 2-s2.0-84952980598>,
#  <Doc: WOS:000366999400015>,
#  <Doc: WOS:000357908000010>,
#  <Doc: WOS:000355036700018>,
#  <Doc: WOS:000377818700003>,
#  <Doc: WOS:000347694800002>,
#  <Doc: 2-s2.0-0842309051>,
#  <Doc: 2-s2.0-33748937531>,
#  <Doc: 2-s2.0-80054058020>,
#  <Doc: 2-s2.0-84555196238>,
#  <Doc: 2-s2.0-84863388384>,
#  <Doc: 2-s2.0-84865343690>,
#  <Doc: 2-s2.0-84874348788>,
#  <Doc: 2-s2.0-84874496279>,
#  <Doc: 2-s2.0-84874859776>,
#  <Doc: 2-s2.0-84875024020>,
#  <Doc: 2-s2.0-84878390350>,
#  <Doc: 2-s2.0-84886368621>,
#  <Doc: 2-s2.0-84888028359>,
#  <Doc: 2-s2.0-84891432920>,
#  <Doc: 2-s2.0-84893645234>,
#  <Doc: 2-s2.0-84893940349>,
#  <Doc: 2-s2.0-84900695214>,
#  <Doc: 2-s2.0-84904173247>,
#  <Doc: 2-s2.0-84906822822>,
#  <Doc: 2-s2.0-84925847320>,
#  <Doc: 2-s2.0-84925970251>,
#  <Doc: 2-s2.0-84942346001>,
#  <Doc: 2-s2.0-84944205798>,
#  <Doc: 2-s2.0-84949257008>,
#  <Doc: 2-s2.0-84949477158>,
#  <Doc: 2-s2.0-84969752962>,
#  <Doc: 2-s2.0-84978255408>,
#  <Doc: 2-s2.0-84994494778>,
#  <Doc: 2-s2.0-85002441941>,
#  <Doc: 2-s2.0-85007194218>,
#  <Doc: 2-s2.0-85009074906>,
#  <Doc: 2-s2.0-85009919368>,
#  <Doc: 2-s2.0-85010223388>,
#  <Doc: 2-s2.0-85010338516>,
#  <Doc: 2-s2.0-85011915238>,
#  <Doc: 2-s2.0-85012085414>,
#  <Doc: 2-s2.0-85013177525>,
#  <Doc: WOS:000075594000003>,
#  <Doc: WOS:000170940900002>,
#  <Doc: WOS:000174503200002>,
#  <Doc: WOS:000177227000005>,
#  <Doc: WOS:000178842400005>,
#  <Doc: WOS:000181689100004>,
#  <Doc: WOS:000182154300002>,
#  <Doc: WOS:000183518800004>,
#  <Doc: WOS:000186387400003>,
#  <Doc: WOS:000221934300036>,
#  <Doc: WOS:000222309300006>,
#  <Doc: WOS:000223361500003>,
#  <Doc: WOS:000223361500004>,
#  <Doc: WOS:000223909700001>,
#  <Doc: WOS:000223909700006>,
#  <Doc: WOS:000226523800003>,
#  <Doc: WOS:000227183600007>,
#  <Doc: WOS:000228363000005>,
#  <Doc: WOS:000229218300004>,
#  <Doc: WOS:000229627500003>,
#  <Doc: WOS:000230265100014>,
#  <Doc: WOS:000230804300012>,
#  <Doc: WOS:000231016400012>,
#  <Doc: WOS:000232265900007>,
#  <Doc: WOS:000232685800005>,
#  <Doc: WOS:000232908800003>,
#  <Doc: WOS:000234087300009>,
#  <Doc: WOS:000236003300001>,
#  <Doc: WOS:000236009100012>,
#  <Doc: WOS:000236776600005>,
#  <Doc: WOS:000236930700008>,
#  <Doc: WOS:000239095700011>,
#  <Doc: WOS:000239189900066>,
#  <Doc: WOS:000239466700004>,
#  <Doc: WOS:000240635800003>,
#  <Doc: WOS:000241292800007>,
#  <Doc: WOS:000243370000002>,
#  <Doc: WOS:000244003700003>,
#  <Doc: WOS:000244163800014>,
#  <Doc: WOS:000245445500003>,
#  <Doc: WOS:000245845600003>,
#  <Doc: WOS:000247230700020>,
#  <Doc: WOS:000247638400014>,
#  <Doc: WOS:000248231500008>,
#  <Doc: WOS:000248831800004>,
#  <Doc: WOS:000249828000014>,
#  <Doc: WOS:000251695100001>,
#  <Doc: WOS:000252663200008>,
#  <Doc: WOS:000252878100015>,
#  <Doc: WOS:000253551600010>,
#  <Doc: WOS:000253929600044>,
#  <Doc: WOS:000254044700006>,
#  <Doc: WOS:000254375100018>,
#  <Doc: WOS:000255343800019>,
#  <Doc: WOS:000256010800002>,
#  <Doc: WOS:000256010800004>,
#  <Doc: WOS:000256030500012>,
#  <Doc: WOS:000258247600011>,
#  <Doc: WOS:000259827000014>,
#  <Doc: WOS:000260941800011>,
#  <Doc: WOS:000261942000008>,
#  <Doc: WOS:000262510500001>,
#  <Doc: WOS:000263398400006>,
#  <Doc: WOS:000263752300008>,
#  <Doc: WOS:000265729900018>,
#  <Doc: WOS:000266201700010>,
#  <Doc: WOS:000266682200005>,
#  <Doc: WOS:000267186700002>,
#  <Doc: WOS:000268659700007>,
#  <Doc: WOS:000269415000030>,
#  <Doc: WOS:000270634100022>,
#  <Doc: WOS:000271256000003>,
#  <Doc: WOS:000272283800004>,
#  <Doc: WOS:000272781700011>,
#  <Doc: WOS:000273176400006>,
#  <Doc: WOS:000274112700010>,
#  <Doc: WOS:000274575800014>,
#  <Doc: WOS:000274730400035>,
#  <Doc: WOS:000274933800002>,
#  <Doc: WOS:000275187300002>,
#  <Doc: WOS:000275254400003>,
#  <Doc: WOS:000275564700009>,
#  <Doc: WOS:000275698700009>,
#  <Doc: WOS:000275757500016>,
#  <Doc: WOS:000275764600003>,
#  <Doc: WOS:000277288900011>,
#  <Doc: WOS:000277874200004>,
#  <Doc: WOS:000278038400009>,
#  <Doc: WOS:000278096700001>,
#  <Doc: WOS:000279152600004>,
#  <Doc: WOS:000279934400003>,
#  <Doc: WOS:000280809600013>,
#  <Doc: WOS:000283502300006>,
#  <Doc: WOS:000283683700027>,
#  <Doc: WOS:000283726600015>,
#  <Doc: WOS:000283872100006>,
#  <Doc: WOS:000285389300021>,
#  <Doc: WOS:000285389300022>,
#  <Doc: WOS:000285769100014>,
#  <Doc: WOS:000287508700003>,
#  <Doc: WOS:000288305400006>,
#  <Doc: WOS:000289026500012>,
#  <Doc: WOS:000289399800015>,
#  <Doc: WOS:000290193600004>,
#  <Doc: WOS:000290492700012>,
#  <Doc: WOS:000291486400012>,
#  <Doc: WOS:000294373400051>,
#  <Doc: WOS:000294800000009>,
#  <Doc: WOS:000295754900022>,
#  <Doc: WOS:000296043800021>,
#  <Doc: WOS:000296571300012>,
#  <Doc: WOS:000297670700015>,
#  <Doc: WOS:000297745800003>,
#  <Doc: WOS:000298532800001>,
#  <Doc: WOS:000298598900004>,
#  <Doc: WOS:000299220200018>,
#  <Doc: WOS:000299508900001>,
#  <Doc: WOS:000300204000015>,
#  <Doc: WOS:000300752700014>,
#  <Doc: WOS:000302106900003>,
#  <Doc: WOS:000302570400012>,
#  <Doc: WOS:000302796200097>,
#  <Doc: WOS:000304321400007>,
#  <Doc: WOS:000304810100002>,
#  <Doc: WOS:000304810100007>,
#  <Doc: WOS:000305377800011>,
#  <Doc: WOS:000307332400002>,
#  <Doc: WOS:000308732700004>,
#  <Doc: WOS:000308974700019>,
#  <Doc: WOS:000309392800076>,
#  <Doc: WOS:000309670200006>,
#  <Doc: WOS:000311149900105>,
#  <Doc: WOS:000311188300038>,
#  <Doc: WOS:000311299800029>,
#  <Doc: WOS:000311875900033>,
#  <Doc: WOS:000313385900010>,
#  <Doc: WOS:000315473000008>,
#  <Doc: WOS:000315473000021>,
#  <Doc: WOS:000315550100014>,
#  <Doc: WOS:000316238300067>,
#  <Doc: WOS:000316818500019>,
#  <Doc: WOS:000317284700022>,
#  <Doc: WOS:000317324300003>,
#  <Doc: WOS:000317926500007>,
#  <Doc: WOS:000318323100021>,
#  <Doc: WOS:000318889100001>,
#  <Doc: WOS:000319826400010>,
#  <Doc: WOS:000320678900006>,
#  <Doc: WOS:000321071800012>,
#  <Doc: WOS:000322064300128>,
#  <Doc: WOS:000322101200008>,
#  <Doc: WOS:000322306800003>,
#  <Doc: WOS:000322827900030>,
#  <Doc: WOS:000322940500017>,
#  <Doc: WOS:000323200200010>,
#  <Doc: WOS:000323246000004>,
#  <Doc: WOS:000323405600001>,
#  <Doc: WOS:000324113400001>,
#  <Doc: WOS:000325488600009>,
#  <Doc: WOS:000325552200088>,
#  <Doc: WOS:000325595800012>,
#  <Doc: WOS:000326239700036>,
#  <Doc: WOS:000327998600028>,
#  <Doc: WOS:000328189400007>,
#  <Doc: WOS:000328716600013>,
#  <Doc: WOS:000328733100007>,
#  <Doc: WOS:000328807400007>,
#  <Doc: WOS:000329349700029>,
#  <Doc: WOS:000331671800008>,
#  <Doc: WOS:000332260000001>,
#  <Doc: WOS:000332261600036>,
#  <Doc: WOS:000333073700050>,
#  <Doc: WOS:000334170800012>,
#  <Doc: WOS:000334265000010>,
#  <Doc: WOS:000334480800001>,
#  <Doc: WOS:000335510600040>,
#  <Doc: WOS:000335515300005>,
#  <Doc: WOS:000335908600006>,
#  <Doc: WOS:000336449000021>,
#  <Doc: WOS:000336700100030>,
#  <Doc: WOS:000337259000064>,
#  <Doc: WOS:000337259100066>,
#  <Doc: WOS:000337672700003>,
#  <Doc: WOS:000338278100002>,
#  <Doc: WOS:000338618400010>,
#  <Doc: WOS:000339712900002>,
#  <Doc: WOS:000339736700013>,
#  <Doc: WOS:000340011800009>,
#  <Doc: WOS:000341340100030>,
#  <Doc: WOS:000341568200019>,
#  <Doc: WOS:000341608900011>,
#  <Doc: WOS:000341608900012>,
#  <Doc: WOS:000341902400007>,
#  <Doc: WOS:000342245600043>,
#  <Doc: WOS:000343164600025>,
#  <Doc: WOS:000343762800022>,
#  <Doc: WOS:000345725800110>,
#  <Doc: WOS:000346594100008>,
#  <Doc: WOS:000347293800004>,
#  <Doc: WOS:000347499100007>,
#  <Doc: WOS:000347608100003>,
#  <Doc: WOS:000348526000009>,
#  <Doc: WOS:000348952400005>,
#  <Doc: WOS:000349980400005>,
#  <Doc: WOS:000350087900024>,
#  <Doc: WOS:000350227000003>,
#  <Doc: WOS:000350896900006>,
#  <Doc: WOS:000351871500022>,
#  <Doc: WOS:000351900900010>,
#  <Doc: WOS:000351975000006>,
#  <Doc: WOS:000352039500039>,
#  <Doc: WOS:000352183200008>,
#  <Doc: WOS:000352745500014>,
#  <Doc: WOS:000352745500018>,
#  <Doc: WOS:000353091600012>,
#  <Doc: WOS:000353384600020>,
#  <Doc: WOS:000353476200028>,
#  <Doc: WOS:000353743300005>,
#  <Doc: WOS:000353963600002>,
#  <Doc: WOS:000355429000005>,
#  <Doc: WOS:000355672800035>,
#  <Doc: WOS:000356191700010>,
#  <Doc: WOS:000356329900036>,
#  <Doc: WOS:000356789100004>,
#  <Doc: WOS:000357019400009>,
#  <Doc: WOS:000357341900016>,
#  <Doc: WOS:000358469200001>,
#  <Doc: WOS:000358469300010>,
#  <Doc: WOS:000358664300005>,
#  <Doc: WOS:000359751600010>,
#  <Doc: WOS:000360644200005>,
#  <Doc: WOS:000360867800030>,
#  <Doc: WOS:000360994500023>,
#  <Doc: WOS:000361864700013>,
#  <Doc: WOS:000362141100027>,
#  <Doc: WOS:000363076500006>,
#  <Doc: WOS:000363311100002>,
#  <Doc: WOS:000363448400002>,
#  <Doc: WOS:000363662700009>,
#  <Doc: WOS:000364596300003>,
#  <Doc: WOS:000366066200041>,
#  <Doc: WOS:000366767100024>,
#  <Doc: WOS:000367413600068>,
#  <Doc: WOS:000367457000016>,
#  <Doc: WOS:000367492800002>,
#  <Doc: WOS:000367522900002>,
#  <Doc: WOS:000367635800044>,
#  <Doc: WOS:000368199300030>,
#  <Doc: WOS:000369463100020>,
#  <Doc: WOS:000369524500013>,
#  <Doc: WOS:000370491400029>,
#  <Doc: WOS:000370912700006>,
#  <Doc: WOS:000371189900018>,
#  <Doc: WOS:000371369600004>,
#  <Doc: WOS:000371520300015>,
#  <Doc: WOS:000371828200004>,
#  <Doc: WOS:000372656100010>,
#  <Doc: WOS:000373138300005>,
#  <Doc: WOS:000373149000007>,
#  <Doc: WOS:000373244700017>,
#  <Doc: WOS:000373949600016>,
#  <Doc: WOS:000374659400014>,
#  <Doc: WOS:000374766500067>,
#  <Doc: WOS:000375337400012>,
#  <Doc: WOS:000376831300004>,
#  <Doc: WOS:000377256900013>,
#  <Doc: WOS:000377277300006>,
#  <Doc: WOS:000377372400025>,
#  <Doc: WOS:000377738500015>,
#  <Doc: WOS:000377922700007>,
#  <Doc: WOS:000380016800023>,
#  <Doc: WOS:000380016800024>,
#  <Doc: WOS:000380761200004>,
#  <Doc: WOS:000380875500002>,
#  <Doc: WOS:000380880500001>,
#  <Doc: WOS:000381060900044>,
#  <Doc: WOS:000381834500008>,
#  <Doc: WOS:000381938700004>,
#  <Doc: WOS:000383300200026>,
#  <Doc: WOS:000383615900006>,
#  <Doc: WOS:000383963700001>,
#  <Doc: WOS:000387212900001>,
#  <Doc: WOS:000387551700011>,
#  <Doc: WOS:000387811300017>,
#  <Doc: WOS:000388098500012>,
#  <Doc: WOS:000388785300080>,
#  <Doc: WOS:000388960300005>,
#  <Doc: WOS:000389089300017>,
#  <Doc: WOS:000389160400007>,
#  <Doc: WOS:000389296700021>,
#  <Doc: WOS:000389630100003>,
#  <Doc: WOS:000390737400006>,
#  <Doc: WOS:000390792700005>,
#  <Doc: WOS:000390964700040>,
#  <Doc: WOS:000391838600033>,
#  <Doc: WOS:000391897300040>,
#  <Doc: WOS:000392061800007>,
#  <Doc: WOS:000392368400001>,
#  <Doc: WOS:000392886700001>,
#  <Doc: WOS:000392886700024>,
#  <Doc: WOS:A1993LZ84600008>,
#  <Doc: WOS:A1994PE61900004>,
#  <Doc: 2-s2.0-84888053714>,
#  <Doc: 2-s2.0-84930686377>,
#  <Doc: WOS:000223108100001>,
#  <Doc: WOS:000224881800001>,
#  <Doc: WOS:000232863200003>,
#  <Doc: WOS:000239189900048>,
#  <Doc: WOS:000243842700001>,
#  <Doc: WOS:000246229800007>,
#  <Doc: WOS:000253786600011>,
#  <Doc: WOS:000254072700076>,
#  <Doc: WOS:000262546800013>,
#  <Doc: WOS:000265010400008>,
#  <Doc: WOS:000266305100004>,
#  <Doc: WOS:000274112700002>,
#  <Doc: WOS:000275187300012>,
#  <Doc: WOS:000275564700014>,
#  <Doc: WOS:000275790400018>,
#  <Doc: WOS:000276769800012>,
#  <Doc: WOS:000278037300005>,
#  <Doc: WOS:000278513800017>,
#  <Doc: WOS:000301689700014>,
#  <Doc: WOS:000307924500007>,
#  <Doc: WOS:000309015800015>,
#  <Doc: WOS:000361880400001>,
#  <Doc: WOS:000363247700016>,
#  <Doc: WOS:000366074400017>,
#  <Doc: WOS:000180209300003>,
#  <Doc: WOS:000182927000001>,
#  <Doc: WOS:000184311800026>,
#  <Doc: WOS:000187290000001>,
#  <Doc: WOS:000221550300007>,
#  <Doc: WOS:000222309300011>,
#  <Doc: WOS:000284360600008>,
#  <Doc: WOS:000288474300009>,
#  <Doc: WOS:000290587100012>,
#  <Doc: WOS:000291739700007>,
#  <Doc: WOS:000294464000016>,
#  <Doc: WOS:000294800000014>,
#  <Doc: WOS:000295957400001>,
#  <Doc: WOS:000375682100005>,
#  <Doc: WOS:000349895300015>,
#  <Doc: WOS:000351789500027>,
#  <Doc: WOS:000244093600003>,
#  <Doc: WOS:000362834200012>,
#  <Doc: WOS:000333667300012>,
#  <Doc: WOS:000332135900003>,
#  <Doc: WOS:000262439000011>,
#  <Doc: WOS:000262743200005>,
#  <Doc: WOS:000301117700080>,
#  <Doc: WOS:000232170500001>,
#  <Doc: WOS:000292308600003>,
#  <Doc: WOS:000275159300003>,
#  <Doc: WOS:000293213600008>,
#  <Doc: WOS:000271824600004>,
#  <Doc: WOS:000299147500003>,
#  <Doc: WOS:000282555000003>,
#  <Doc: WOS:000286088700010>,
#  <Doc: WOS:000300006100004>,
#  <Doc: WOS:000272499000014>,
#  <Doc: 2-s2.0-33745598771>,
#  <Doc: WOS:000299147500002>,
#  <Doc: WOS:000244686900007>,
#  <Doc: WOS:000081736900003>,
#  <Doc: 2-s2.0-33750282659>,
#  <Doc: WOS:000087564500004>,
#  <Doc: WOS:000182099300003>,
#  <Doc: WOS:000183217700001>,
#  <Doc: WOS:000183734200001>,
#  <Doc: WOS:000167741500001>,
#  <Doc: WOS:000306200100027>,
#  <Doc: WOS:000171220800005>,
#  <Doc: WOS:000312131100001>,
#  <Doc: WOS:000258075100065>,
#  <Doc: WOS:000253620000004>,
#  <Doc: WOS:000390494800091>,
#  <Doc: WOS:000334414900026>,
#  <Doc: WOS:000393003100004>,
#  <Doc: 2-s2.0-67650707059>]

# %%
pdoc_dict = []

allrelids = list(allreldocs.values_list('UT',flat=True))

for doc in pdocs:
    das = doc.docauthinst_set.order_by('AU','position').distinct('AU').values_list('id',flat=True)
    unique = doc.docauthinst_set.filter(id__in=das).order_by('position').values_list('AU',flat=True)
    qset = [str(x) for x in list(doc.query.filter(
            technology__in=techs,type="default"
        ).distinct().values_list('id',flat=True))]
    try:
        py = int(doc.PY)
    except:
        py = doc.PY
    if doc.UT in foundpapers['doc_id']:
        sp = 1
    else:
        sp = 0
    if doc.UT in allrelids:
        r = 1
    else:
        r = 0
    pdoc = {
        'Authors': "; ".join(unique),
        'Publication_Year': py,
        'Title': doc.title,
        'Queries': "; ".join(qset),
        'Relevant': r,
        'In_Spreadsheet': sp
    }
    pdoc_dict.append(pdoc)

# %%
big_df = pd.DataFrame.from_dict(pdoc_dict)

big_df.head(155)
# Out:
#                                                Authors  In_Spreadsheet  \
# 0                                          Mason, S.S.               0
# 1                                          Englert, R.               0
# 2                                             Alig, R.               0
# 3    Dubey, M.K.; Ziock, H.; Rueff, G.; Elliott, S....               0
# 4                                         MacLaren, P.               0
# 5    Lemon, J.; Wilson, B.; Eyears-Chaddock, M.; Ma...               0
# 6                                              Kim, M.               0
# 7                                        Randall, C.C.               0
# 8                                           Cole, L.J.               0
# 9                                             MAYNET G               0
# 10                                        Karamata, D.               0
# 11                                         Borberg, H.               0
# 12                                        Robins, A.B.               0
# 13                                          Hill, J.M.               0
# 14                                         Means, A.R.               0
# 15                                         Dang, V.-D.               0
# 16                                       Marchetti, C.               0
# 17                                  Glaudemans, C.P.J.               0
# 18                                         Wolfe, R.S.               0
# 19                                         Wolfe, R.S.               0
# 20                                      Keltjens, J.T.               0
# 21                                      Thompson, M.E.               0
# 22                                       Levinthal, C.               0
# 23                                 Benjamin, Thomas G.               0
# 24                                     Abbott, Mark R.               0
# 25                                         Nicol, S.C.               0
# 26                                       Gifford, R.M.               0
# 27                      Johnson, W.C.; Schiffman, P.M.               0
# 28                                      Guzelian, P.S.               0
# 29                                    Siegenthaler, U.               0
# ..                                                 ...             ...
# 125                                   Timmermans, K.R.               0
# 126                                                                  0
# 127                                      Snorrason, A.               0
# 128                 Cui, L.; Shi, J.; Liu, J.; Gao, Z.               0
# 129                                    De Baar, H.J.W.               0
# 130                                          Zeman, F.               0
# 131                                    Hendrickson, O.               0
# 132  Mallett, K.I.; Volney, W.J.A.; Alfaro, R.I.; B...               0
# 133                                          Keith, D.               0
# 134  Hänchen, M.; Storti, G.; Prigiobbe, V.; Mazzot...               0
# 135                                           Read, P.               0
# 136                                      Vesterdal, L.               0
# 137      Crisp, D.; Haring, R.; Pollock, R.; Sutin, B.               0
# 138        Hofstede, R.G.M.; Farley, K.A.; Kelly, E.F.               0
# 139                                                                  0
# 140                                       Chang, C.-C.               0
# 141                                          Perks, B.               0
# 142                          Rogner, H.-H.; Toth, F.L.               0
# 143           Freund, P.; F; r; e; u; n; d; ,;  ; P; .               0
# 144                                                                  0
# 145                         Davidson, S.; Maitland, G.               0
# 146                                         Boyd, P.W.               0
# 147                          Lasco, R.D.; Pulhin, J.M.               0
# 148                              Hu, H.-F.; Liu, G.-H.               0
# 149                                            Lal, R.               0
# 150  Kanninen, M.; Montagnini, F.; Cusack, D.; Peti...               0
# 151                                         Kälber, S.               0
# 152               Hanrot, F.; Danloy, G.; Birat, J.-P.               0
# 153                                        Gibbons, W.               0
# 154  Mielniczuk, J.; De Souza Costa, F.; Gomes, J.;...               0
#
#      Publication_Year                        Queries  Relevant  \
# 0              1993.0                  374; 672; 896         0
# 1              1991.0       369; 468; 661; 662; 1481         0
# 2              2000.0                       334; 618         0
# 3              2002.0       369; 468; 661; 662; 1481         0
# 4              1999.0                       334; 618         0
# 5              2002.0                       334; 618         0
# 6              2002.0                  374; 672; 896         0
# 7              1968.0                  374; 672; 896         0
# 8              1968.0                  374; 672; 896         0
# 9              1970.0                  374; 672; 896         0
# 10             1972.0                  374; 672; 896         0
# 11             1972.0                  374; 672; 896         0
# 12             1973.0                  374; 672; 896         0
# 13             1975.0                  374; 672; 896         0
# 14             1977.0                  374; 672; 896         0
# 15             1977.0       369; 468; 661; 662; 1481         0
# 16             1979.0               1472; 1473; 1474         0
# 17             1981.0                  374; 672; 896         0
# 18             1982.0                  374; 672; 896         0
# 19             1983.0                  374; 672; 896         0
# 20             1984.0                  374; 672; 896         0
# 21             1986.0                  374; 672; 896         0
# 22             1986.0                  374; 672; 896         0
# 23             1986.0                  374; 672; 896         0
# 24             1987.0                       367; 673         0
# 25             1988.0       369; 468; 661; 662; 1481         0
# 26             1988.0                       334; 618         0
# 27             1989.0                       334; 618         0
# 28             1990.0                  374; 672; 896         0
# 29             1991.0                            338         0
# ..                ...                            ...       ...
# 125            2005.0                            338         0
# 126            2005.0                       367; 673         0
# 127            2000.0                       334; 618         0
# 128            2005.0      332; 334; 618; 1241; 1254         0
# 129            2005.0                            338         0
# 130            2004.0       369; 468; 661; 662; 1481         0
# 131            2003.0                       334; 618         0
# 132            2005.0                       334; 618         0
# 133            2004.0       369; 468; 661; 662; 1481         0
# 134            2005.0                       585; 586         0
# 135            2005.0  367; 374; 672; 673; 896; 1458         0
# 136            2000.0                       334; 618         0
# 137            2005.0                  374; 672; 896         0
# 138            2004.0                       334; 618         0
# 139            2005.0                       334; 618         0
# 140            1999.0                       334; 618         0
# 141            2004.0                            338         0
# 142            2006.0                 367; 673; 1458         0
# 143            2000.0                            651         0
# 144            2005.0                       367; 673         0
# 145            2005.0                       367; 673         0
# 146            2006.0                            338         0
# 147            2006.0                       334; 618         0
# 148            2006.0                       334; 618         0
# 149            2005.0                332; 1241; 1254         0
# 150            2005.0                       334; 618         0
# 151            2005.0                            651         0
# 152            2004.0                       367; 673         0
# 153            2005.0                       367; 673         0
# 154            2006.0                332; 1241; 1254         0
#
#                                                  Title
# 0    Syntheses and 13C NMR Investigations of an Ext...
# 1    Automated trace analysis of airborne C1- and C...
# 2    Mitigation, adaptation, and climate change: Re...
# 3    Extraction of carbon dioxide from the atmosphe...
# 4    Modelling the effect of land-use practices on ...
# 5    Soil changes under 'habitat reconstruction' si...
# 6    Synthesis of cross-conjugated olefins from alk...
# 7    Kinetics of cellular and viral DNA synthesis i...
# 8    Plasma Deoxycytidine: Increased Levels after X...
# 9    THERMOGRAVIMETRIC STUDY OF THE GAS CARBURIZING...
# 10   Temperature-sensitive mutants of B. subtilis d...
# 11   Characterization of Protein and DNA in P815 Ce...
# 12   The reaction of 14C-labelled platinum ethylene...
# 13   Metabolism of Deoxycytidine, Thymine, and Deox...
# 14   Identification of ε-N-trimethyllysine in a rat...
# 15   Production of synthetic methanol from air and ...
# 16   l012: A check on the earth-carrying capacity f...
# 17   A hypothetical space-filling model of the V-re...
# 18   CDR factor, a new coenzyme required for carbon...
# 19   Carbon dioxide reduction factor and methanopte...
# 20   Coenzymes of methanogenesis from hydrogen and ...
# 21   The cation denudation rate model - Its continu...
# 22   Predicting antibody hypervariable loop conform...
# 23   MOLTEN CARBONATE FUEL CELL COMPONENT DESIGN RE...
# 24   SATELLITE STUDIES OF BIOLOGICAL AND PHYSICAL P...
# 25   Ventilation and oxygen extraction in the littl...
# 26                        Interactions with vegetation
# 27   Phytomass and detrital carbon storage during f...
# 28   Isolation and Characterization of Cloned cDNAs...
# 29   Estimates of the effect of Southern Ocean iron...
# ..                                                 ...
# 125  Changes in the concentration of iron in differ...
# 126   IEA study: Prospects for CO2 capture and storage
# 127  Carbon sequestration by afforestation and reve...
# 128  A review on the influence of afforestation on ...
# 129  Spatial and temporal distribution of Fe(II) an...
# 130      Carbon dioxide extraction from the atmosphere
# 131  Influences of global change on carbon sequestr...
# 132  A framework for poplar plantation risk assessm...
# 133  CO 2 extraction from ambient air using alkali-...
# 134  Kinetic study of silicate dissolution for the ...
# 135  Food for thought - World trade in biofuels off...
# 136             Carbon sequestration in Danish forests
# 137  Current development status of the Orbiting Car...
# 138  Soil organic carbon and water retention after ...
# 139  Developing a conceptual methodology for succes...
# 140  Carbon sequestration cost by afforestation in ...
# 141                             Ironing out rising CO2
# 142  Carbon dioxide capture: An assessment of plaus...
# 143  Reducing methane emissions to combat climate c...
# 144                         Nordic resource management
# 145     Process technologies: Pipe-dream meets reality
# 146  Development of a robust marine ecosystem model...
# 147  Environmental impacts of community-based fores...
# 148  Carbon sequestration of China's National Natur...
# 149  Soil carbon sequestration in natural and manag...
# 150  Environmental services of native tree plantati...
# 151  Renewable resources for electricity production...
# 152  Perspectives of CO2 emissions reduction in iro...
# 153  Production of polyhydroxyalkanoates from cellu...
# 154  Methods for the assessment of greenhouse gases...
#
# [155 rows x 6 columns]

# %%
big_df.groupby('In_Spreadsheet').count()
# Out:
#                 Authors  Publication_Year  Queries  Relevant  Title
# In_Spreadsheet
# 0                  7604              7603     7604      7604   7603

# %%
for q in queries[:10]:
    ds = q.doc_set.all()
    dids = list(q.doc_set.all().values_list('UT',flat=True))
    ds = Doc.objects.filter(UT__in=dids)
    print(ds.count())
    ds = ds.annotate(
        qs = Count('query')
    )
    print(ds.filter(qs__lt=4).count())
    
    print(q.title)
# Out:
# 68
# 0
# enhanced_weathering_wos
# 2
# 0
# forests1_backward_1_1
# 3
# 0
# *7B_BlueDemos
# 101
# 0
# enhanced_weathering_wos_2
# 637
# 0
# soil_carbon_sequestration_scopus
# 4
# 0
# DAC_extra
# 422
# 9
# synonyms_all
# 660
# 0
# soil_carbon_sequestration
# 396
# 0
# beccs_scopus
# 391
# 6
# synonyms_scopus

# %%
q = queries.first()

ds = q.doc_set.all()

print(ds.count())

ds = ds.annotate(
    qs = Count('query')
)

print(ds.filter(qs__lt=2).count())

q.title
# Out:
# 198
# 198
# 'NETs_scoping_DAC'

# %%
trdocs = set(list(pdocs.filter(
    docownership__relevant=1,
    docownership__query__technology__in=techs
).values_list('UT',flat=True)))

ttdocs = set(list(Doc.objects.filter(
    technology__in=techs
).values_list('UT',flat=True)))

print(len(trdocs))
print(len(ttdocs))

allreldocs =  Doc.objects.filter(
    UT__in=trdocs.union(ttdocs)
)

print(allreldocs.count())

print(allreldocs.order_by('PY').first().PY)
print(allreldocs.order_by('PY').first().title)

print(allreldocs.filter(PY__lt=1990).count())

# %%
import django, os, sys, time, resource, re, gc, shutil
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from django.db.models import Count, Avg, F, Sum
import math

sys.path.append('/home/galm/software/django/tmv/BasicBrowser/')

os.environ.setdefault("DJANGO_SETTINGS_MODULE", "BasicBrowser.settings")
django.setup()

from scoping.models import *
from utils.utils import ars

qid = 1558
q = Query.objects.get(pk=qid)

# %%
p = Project.objects.get(title="NETs")
pdocs = Doc.objects.filter(query__project=p)

techs = Technology.objects.filter(project=p).exclude(name__in=["Bioenergy","Storage","Blue Carbon"])

tdocs = set(list(Doc.objects.filter(
    technology__in=techs
).values_list('UT',flat=True)))

qtdocs = set(list(Doc.objects.filter(
    query__technology__in=techs
).values_list('UT',flat=True)))

## These are all docs in the project

pdocs =  Doc.objects.filter(
    UT__in=tdocs.union(qtdocs)
)

print(pdocs.distinct().count())#techs = Technology.objects.filter(project=p)
# Out:
# 7519

# %%
queries = Query.objects.filter(technology__in=techs,doc__isnull=False,type="default").distinct()

qts = queries.annotate(
    ndocs = Count('doc')
)

qtdf = pd.DataFrame.from_dict(list(qts.values('id','technology__name','ndocs','title','text','database')))

qtdf.head()
# Out:
#   database    id  ndocs           technology__name  \
# 0   manual  1531      1        Ocean fertilisation
# 1      WoS   337    115        Ocean fertilisation
# 2      WoS   330    660  Soil Carbon Sequestration
# 3   manual  1494      1            Ethics & Morals
# 4   intern  1199    105        Ocean fertilisation
#
#                                                 text  \
# 0  Manually add Ocean fertilization_Enhanced upwe...
# 1  TS = (ocean NEAR/5 iron NEAR/5 (fertili*ation ...
# 2  TS = ((soil NEAR/3 (carbon OR CO2) NEAR/3 (seq...
# 3  Manually add     Getting the Bad Out: remediat...
# 4                                  1125 AND 1175\r\n
#
#                                                title
# 0  Manual add Ocean fertilization_Enhanced upwelling
# 1                            ocean_fertilisation_WoS
# 2                          soil_carbon_sequestration
# 3  Manual add     Getting the Bad Out: remediatio...
# 4                              *2F_OceanPublicaccept

# %%
trdocs = set(list(pdocs.filter(
    docownership__relevant=1,
    docownership__query__technology__in=techs
).values_list('UT',flat=True)))

ttdocs = set(list(Doc.objects.filter(
    technology__in=techs
).values_list('UT',flat=True)))


allreldocs =  Doc.objects.filter(
    UT__in=trdocs.union(ttdocs)
)

print(allreldocs.count())
# Out:
# 1984

# %%
global unfound
unfound = 0

global multmatches
multmatches = 0

global found
found = 0

global indb
indb = 0

spapers = pd.read_csv('../tables/unique_spreadsheet_papers.csv')


def find_paper(x):
    
    try:
    
        tis = x['X3'].split()
        
    except:
        print(x['X3'])
        tis = str(x['X3']).split()
    
    if len(tis) > 8:
        ti = ' '.join(tis[:8])
    else:
        ti = x['X3']
        
    docs = allreldocs.filter(title__icontains=ti)
    
    global unfound
    global found
    global multmatches
    
    if docs.count() == 1:
    
        doc = docs.first()
        found +=1
    elif docs.count() > 1:
        doc = "None"
        multmatches+=1
    else:       
        di = x['X3'].replace('http://dx.doi.org/','')
        docs = allreldocs.filter(wosarticle__di=di)
        if docs.count()==1:
            doc = docs.first()
            found+=1
        elif docs.count() > 1:
            doc = "None"
            multmatches+=1
        else:
            au = x['X1'].split()[0].split(',')[0]
            docs = allreldocs.filter(docauthinst__AU__icontains=au,docauthinst__position=1,PY=x['X2']).distinct()
            if docs.count()==1:
                doc = docs.first()
                found+=1
            elif docs.count() > 1:
                doc = "None"
                multmatches+=1
            else:
                ti = re.findall('[A-Z]{1}\.{1}[^;]([^\.]{5,})',x['X3'])
                if len(ti) > 0:
                    ti = ti[0]
                else:
                    ti = "zwasdfölkjag"
                docs = allreldocs.filter(title__icontains=ti)
                if docs.count()==1:
                    doc = docs.first()
                    found+=1
                else:
                    doc = "None"
                    unfound+=1
    
    return doc

spapers['doc_id'] = spapers.apply(lambda x: find_paper(x), axis=1)

print("no matches: {}".format(unfound))
print("multiple matches: {}".format(multmatches))
print("found {}".format(found))


spapers.head()
# Out:
# nan
# no matches: 83
# multiple matches: 3
# found 775
#    Unnamed: 0                     X1      X2  \
# 0           1            Renforth, P  2012.0
# 1           3  Schuiling & Krijgsman  2006.0
# 2           4          Köhler et al.  2010.0
# 3           5          Taylor et al.  2016.0
# 4           6         Hangx & Spiers  2009.0
#
#                                                   X3 Data categorisation  \
# 0     The potential of enhanced weathering in the UK                 NaN
# 1  ENHANCED WEATHERING: AN EFFECTIVE AND CHEAP TO...                 NaN
# 2  Geoengineering potential of artificially enhan...                 NaN
# 3  Enhanced weathering strategies for stabilizing...                2100
# 4  Coastal spreading of olivine to control atmosp...                1990
#
#                 doc_id
# 0  WOS:000309790500021
# 1  WOS:000237646500016
# 2  WOS:000284529000019
# 3  WOS:000373060000019
# 4  WOS:000272373000010

# %%
found
# Out:
# 360

# %%
spapers[spapers['doc_id'] == "None"].reset_index()['X3']


spapers[spapers['doc_id'] == "None"].reset_index()[18:35]                                               

# Go through docs, mark include1 if in allreldocs, mark include2 if in list generated in R


#spapers[spapers['doc_id'] == "None"].reset_index()['X3'][18]
# Out:
#     index  Unnamed: 0                                                 X1  \
# 18    785         934                                             Ahamer
# 19    786         935  Calvin, K; Wise, M; Luckow, P; Kyle, P; Clarke...
# 20    787         937                                    Nordstrm, E.-M.
# 21    788         938                               Searle, S; Malins, C
# 22    790         940  Smeets, EMW; Faaij, APC; Lewandowski, IM; Turk...
# 23    793         947  Lauri, P; Havlik, P; Kindermann, G; Forsell, N...
# 24    794         948                         Metzger, JO; Huttermann, A
# 25    795         949  Hoogwijk, M; Hoogwijk, M; Faaij, A; de Vries, ...
# 26    796         950  Mendu, V; Shearin, T; Campbell, JE; Campbell, ...
# 27    797         951  Hoogwijk, M; Faaij, A; Eickhout, B; de Vries, ...
# 28    798         956  Beringer, T; Beringer, T; Lucht, W; Lucht, W; ...
# 29    799         957  Dornburg, V; van Vuuren, D; van de Ven, G; Lan...
# 30    800         958  Wicke, B; Wicke, B; Wicke, B; Smeets, E; Smeet...
# 31    801         959          van Vuuren, DP; van Vliet, J; Stehfest, E
# 32    803         965                    Gregg, JS; Gregg, JS; Smith, SJ
# 33    804         967  Haberl, H; Beringer, T; Bhattacharya, SC; Erb,...
# 34    805         970  Nijsen, M; Smeets, E; Stehfest, E; van Vuuren, DP
#
#         X2                                                 X3  \
# 18  1996.0  Biomass energy production: the Global Potentia...
# 19  2016.0  Implications of uncertain future fossil energy...
# 20  2015.0  Bioenergy futures: A global outlook on the imp...
# 21  2015.0  A reassessment of global bioenergy potential i...
# 22  2007.0  A bottom-up assessment and review of global bi...
# 23  2014.0             Woody biomass energy potential in 2050
# 24  2009.0  Sustainable global energy supply based on lign...
# 25  2009.0  Exploration of regional and global cost-supply...
# 26  2012.0  Global bioenergy potential from high-lignin ag...
# 27  2005.0  Potential of biomass energy out to 2100, for f...
# 28  2011.0  Bioenergy production potential of global bioma...
# 29  2010.0  Bioenergy revisited: Key factors in global pot...
# 30  2011.0  The global technical and economic potential of...
# 31  2009.0  Future bio-energy potential under various natu...
# 32  2010.0  Global and regional potential for bioenergy fr...
# 33  2010.0  The global technical potential of bio-energy i...
# 34  2012.0  An evaluation of the global potential of bioen...
#
#    Data categorisation doc_id
# 18                2100   None
# 19                2050   None
# 20                2050   None
# 21                2050   None
# 22                2050   None
# 23                2050   None
# 24                2030   None
# 25                2050   None
# 26                 NaN   None
# 27                2050   None
# 28                2050   None
# 29                2050   None
# 30                 NaN   None
# 31                2050   None
# 32                2050   None
# 33                2050   None
# 34                 NaN   None

# %%
for q in queries[:10]:
    ds = q.doc_set.all()
    dids = list(q.doc_set.all().values_list('UT',flat=True))
    ds = Doc.objects.filter(UT__in=dids)
    print(ds.count())
    ds = ds.annotate(
        qs = Count('query')
    )
    print(ds.filter(qs__lt=4).count())
    
    print(q.title)
# Out:
# 68
# 0
# enhanced_weathering_wos
# 2
# 0
# forests1_backward_1_1
# 3
# 0
# *7B_BlueDemos
# 101
# 0
# enhanced_weathering_wos_2
# 637
# 0
# soil_carbon_sequestration_scopus
# 4
# 0
# DAC_extra
# 422
# 9
# synonyms_all
# 660
# 0
# soil_carbon_sequestration
# 396
# 0
# beccs_scopus
# 391
# 6
# synonyms_scopus

# %%
q = queries.first()

ds = q.doc_set.all()

print(ds.count())

ds = ds.annotate(
    qs = Count('query')
)

print(ds.filter(qs__lt=2).count())

q.title
# Out:
# 198
# 198
# 'NETs_scoping_DAC'

# %%
trdocs = set(list(pdocs.filter(
    docownership__relevant=1,
    docownership__query__technology__in=techs
).values_list('UT',flat=True)))

ttdocs = set(list(Doc.objects.filter(
    technology__in=techs
).values_list('UT',flat=True)))

print(len(trdocs))
print(len(ttdocs))

allreldocs =  Doc.objects.filter(
    UT__in=trdocs.union(ttdocs)
)

print(allreldocs.count())

print(allreldocs.order_by('PY').first().PY)
print(allreldocs.order_by('PY').first().title)

print(allreldocs.filter(PY__lt=1990).count())
